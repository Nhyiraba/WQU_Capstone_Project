# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.84)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)

# %%
pip install backtesting
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: backtesting in /usr/local/lib/python3.7/dist-packages (0.3.3)
# Requirement already satisfied: bokeh>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from backtesting) (2.3.3)
# Requirement already satisfied: pandas!=0.25.0,>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from backtesting) (1.3.5)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from backtesting) (1.21.6)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (6.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (5.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (4.1.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (2.8.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (2.11.3)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh>=1.4.0->backtesting) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh>=1.4.0->backtesting) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh>=1.4.0->backtesting) (1.15.0)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import pandas_datareader as pdr
import pandas_datareader.data as web
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from scipy.stats import skew
from scipy.stats import kurtosis
import datetime
from sklearn import linear_model
import math
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from numpy import asarray
from scipy.stats import pearsonr
import seaborn as sns
from datetime import date, timedelta, datetime
from dateutil import parser
from matplotlib import pyplot as plt
from sklearn.tree import export_text
from sklearn import tree, datasets
import jinja2
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, classification_report, accuracy_score, confusion_matrix
from backtesting import Backtest, Strategy
from backtesting.lib import crossover

# %%
vix_futures_csv = 'https://raw.githubusercontent.com/Nhyiraba/WQU_Capstone_Project/master/data/vix_futures.csv'

# https://github.com/Nhyiraba/WQU_Capstone_Project/blob/main/data/vix_futures.csv

vix_futures = pd.read_csv(vix_futures_csv, parse_dates=True)

# %%
vix_futures.index = pd.to_datetime(vix_futures['Date']).dt.date

# %%
vix_df=vix_futures.drop(columns=['Date','VXX']).iloc[:,0:5]

# %%
vix_df=vix_df[::-1]

# %%
vix_df.index=pd.to_datetime(vix_df.index)

# %%
download = "^GSPC ^IXIC ^VIX"
df = yf.download(download, start = "2006-01-01", end = "2022-12-31")["Adj Close"]
df1 = yf.download("^GSPC ^IXIC ^VIX VXX VXZ", start = "2018-01-26", end = "2022-10-15")["Adj Close"]
# Out:
# [*********************100%***********************]  3 of 3 completed
# [*********************100%***********************]  5 of 5 completed

# %%
# quick decriptive statistics 
def descriptiveStatistics(df):
  dfstats = vix_df.describe()
  dfstats.loc['variance'] = df.var().tolist()
  dfstats.loc['skewness'] = df.skew().tolist()
  dfstats.loc['kurtosis'] = df.kurtosis().tolist()

  # formatting the values
  dfstats.loc['count'] = dfstats.loc['count'].astype(int).astype(str)
  dfstats.iloc[1:] = dfstats.iloc[1:].applymap('{:.4f}'.format)

  return dfstats

# %%
descriptiveStatistics(vix_df)
# Out:
#               VIX       M1       M2    VIX3M          SPX
# count        1540     1540     1540     1540         1540
# mean      18.1659  18.8232  19.8007  20.2337    3043.1163
# std        8.2956   7.2181   6.5318   7.3471     756.4718
# min        9.1100   9.8800  11.3000  11.9200    1978.3500
# 25%       12.7375  14.1000  15.3175  15.2200    2472.4450
# 50%       16.0100  16.8000  17.6650  17.8800    2838.3350
# 75%       21.2325  21.4100  22.6625  23.2050    3401.0275
# max       82.6900  72.6000  60.7500  72.9800    4796.5601
# variance  68.8168  52.1013  42.6650  53.9803  572249.5542
# skewness   2.7320   2.3020   1.6666   2.1056       0.7841
# kurtosis  12.2301   9.2121   4.5325   7.6473      -0.4797

# %%
df1["diff"]=df1["VXZ"]-df1["VXX"]

# %%
df1.describe()
# Out:
#                VXX          VXZ        ^GSPC         ^IXIC         ^VIX  \
# count  1189.000000  1189.000000  1189.000000   1189.000000  1189.000000
# mean     86.477051    24.818538  3439.851950  10459.864385    21.357721
# std      53.161156     5.881459   676.877955   2850.211994     8.559735
# min      17.629999    16.440001  2237.399902   6192.919922    10.850000
# 25%      28.860001    18.940001  2843.489990   7837.129883    15.600000
# 50%      88.800003    25.719999  3239.909912   9750.969727    19.510000
# 75%     125.720001    29.629999  4110.410156  13129.959961    25.350000
# max     276.000000    38.540001  4796.560059  16057.440430    82.690002
#
#               diff
# count  1189.000000
# mean    -61.658512
# std      54.959005
# min    -237.459999
# 25%    -104.644997
# 50%     -64.810001
# 75%      -2.160000
# max       9.890001

# %%
plt.figure(figsize =(10,4))
plt.plot(df1['^GSPC'], color = '#2980B9', linewidth = 1, label = 'S&P500')
plt.title("^GSPC S&P500")
# Out:
# Text(0.5, 1.0, '^GSPC S&P500')

# %%
plt.figure(figsize =(10,4))
plt.plot(df['^VIX'], color = '#2980B9', linewidth = 1, label = 'S&P500')
plt.title("^VIX")
# Out:
# Text(0.5, 1.0, '^VIX')

# %%
plt.figure(figsize =(10,4))
plt.plot(vix_df['VIX'], color = '#2980B9', linewidth = 1, label = 'VIX ')
plt.title("VIX ")
# Out:
# Text(0.5, 1.0, 'VIX ')

# %%
plt.figure(figsize =(10,4))
plt.plot(vix_df['M1'], color = '#2980B9', linewidth = 1, label = 'VIX Future M1')
plt.title("VIX Future M1")
# Out:
# Text(0.5, 1.0, 'VIX Future M1')

# %%
plt.figure(figsize =(10,4))
plt.plot(vix_df['M2'], color = '#2980B9', linewidth = 1, label = 'VIX - M2')
plt.title("VIX - M2")
# Out:
# Text(0.5, 1.0, 'VIX - M2')

# %%
plt.figure(figsize =(10,4))
plt.plot(vix_df['VIX3M'], color = '#2980B9', linewidth = 1, label = 'VIX - M3')
plt.title("VIX - M3")
# Out:
# Text(0.5, 1.0, 'VIX - M3')

# %% [markdown]
# # Combined plot for "VIX, VIX Future and 'VIX - M2'"

# %%
plt.figure(figsize =(14,7))
plt.plot(vix_df['VIX'], color = 'red', linewidth = 1, label = 'VIX ')
plt.plot(vix_df['M1'], color = 'blue', linewidth = 1, label = 'VIX 1-month future')
plt.plot(vix_df['M2'], color = 'green', linewidth = 1, label = 'VIX 2-month future')
plt.plot(vix_df['VIX3M'], color = 'yellow', linewidth = 1, label = 'VIX 3-month future')
plt.title("VIX and future'")
plt.legend()

# %%
vix_df
# Out:
#               VIX     M1     M2  VIX3M        SPX
# Date
# 2016-03-01  17.70  19.40  20.30  20.28  1978.3500
# 2016-03-02  17.09  19.30  20.25  19.92  1986.4500
# 2016-03-03  16.70  18.35  19.50  19.49  1993.4000
# 2016-03-04  16.86  18.95  20.00  19.63  1999.9900
# 2016-03-07  17.35  18.60  19.80  19.90  2001.7600
# ...           ...    ...    ...    ...        ...
# 2022-04-04  18.57  21.00  23.21  23.03  4582.6401
# 2022-04-05  21.03  22.85  24.55  24.90  4525.1201
# 2022-04-06  22.10  23.95  25.53  25.80  4481.1499
# 2022-04-07  21.55  22.72  24.62  25.23  4500.2100
# 2022-04-08  21.16  22.60  24.60  25.17  4488.2798
#
# [1540 rows x 5 columns]

# %%
(vix_df["VIX"] - vix_df["M1"]).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Simple Moving avarage

# %%
def perform_adf_test(series):
    result=adfuller(series)
    print ('ADF stats: %f' % result[0])
    print('p-value: %f' % result[1])

# %%
def SMA(data,period = 30, column ='Close'):
  return data[column].rolling(window = period).mean()

# %%
SMA(vix_df,21,'VIX')
# Out:
# Date
# 2016-03-01          NaN
# 2016-03-02          NaN
# 2016-03-03          NaN
# 2016-03-04          NaN
# 2016-03-07          NaN
#                 ...
# 2022-04-04    25.332381
# 2022-04-05    24.598095
# 2022-04-06    23.977619
# 2022-04-07    23.458571
# 2022-04-08    23.026667
# Name: VIX, Length: 1540, dtype: float64

# %%
plt.figure(figsize =(14,7))
smadf = SMA(vix_df,21,'VIX')
smadf.plot(title ="Moving Average for VIX using 21 days window")
# plt.axhline(smadf.max(),c='red',label='Max SMA')
# plt.axhline(smadf.min(),c='green',label='Min SMA')
plt.ylabel("Prices")
plt.legend()

# %%
SMA(vix_df,21,'VIX').describe()
# Out:
# count    1520.000000
# mean       18.155335
# std         7.683835
# min         9.800476
# 25%        13.037024
# 50%        16.266190
# 75%        21.005476
# max        61.217143
# Name: VIX, dtype: float64

# %%
#only VIX is stationary 
#only VIX is stationary 
#perform_adf_test(vix_df.VIX),perform_adf_test(vix_df.M1),
perform_adf_test(vix_df.M2),perform_adf_test(vix_df.VIX3M),perform_adf_test(vix_df.SPX),perform_adf_test(df1['^GSPC']),perform_adf_test(df1['^VIX']),
perform_adf_test(df1['diff'])
# Out:
# ADF stats: -3.042524
# p-value: 0.031110
# ADF stats: -2.887402
# p-value: 0.046833
# ADF stats: -0.331381
# p-value: 0.920941
# ADF stats: -1.456018
# p-value: 0.555146
# ADF stats: -3.841765
# p-value: 0.002508
# ADF stats: -1.396109
# p-value: 0.584140

# %%
adfuller(vix_df.VIX)
# Out:
# (-4.0755629578384465,
#  0.001062632025884834,
#  9,
#  1530,
#  {'1%': -3.434631245212095,
#   '5%': -2.8634309048528066,
#   '10%': -2.5677766901619035},
#  6430.891961998817)

# %%
vix_df
# Out:
#               VIX     M1     M2  VIX3M        SPX
# Date
# 2016-03-01  17.70  19.40  20.30  20.28  1978.3500
# 2016-03-02  17.09  19.30  20.25  19.92  1986.4500
# 2016-03-03  16.70  18.35  19.50  19.49  1993.4000
# 2016-03-04  16.86  18.95  20.00  19.63  1999.9900
# 2016-03-07  17.35  18.60  19.80  19.90  2001.7600
# ...           ...    ...    ...    ...        ...
# 2022-04-04  18.57  21.00  23.21  23.03  4582.6401
# 2022-04-05  21.03  22.85  24.55  24.90  4525.1201
# 2022-04-06  22.10  23.95  25.53  25.80  4481.1499
# 2022-04-07  21.55  22.72  24.62  25.23  4500.2100
# 2022-04-08  21.16  22.60  24.60  25.17  4488.2798
#
# [1540 rows x 5 columns]

# %% [markdown]
# Multiplot

# %%
#fig = plt.figure(figsize =(14,10))
# fig, ax = plt.subplots(2, 2,figsize=(15,10))
#fig.suptitle('Sharing x per column, y per row')
# plot_pacf(df1['^VIX'], ax=plt.gca())

# pacf_plot=plot_acf(df1['^VIX'],ax=axs[2])
# acf_plot= plot_acf(vix_df['M1'],ax=axs[3])


plt.figure(figsize =(14,10)) 
plt.subplot(221) 
plot_pacf(df1['^VIX'], ax=plt.gca());
plt.subplot(222)
plot_pacf(vix_df['M1'], ax=plt.gca());
plt.subplot(223) 
plot_acf(df1['^VIX'],ax=plt.gca());
plt.subplot(224) 
plot_acf(vix_df['M1'],ax=plt.gca());
# plt.show()
# Out:
# /root/.local/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
# pacf_plot=plot_pacf(df1['^VIX']);

# %%
# pacf_plot= plot_pacf(vix_df['M1']);

# %%
# acf_plot= plot_acf(df1['^VIX']);

# %%
# acf_plot= plot_acf(vix_df['M1']);

# %%
#ARMA model for VIX
first_diffs_sp500=(df1['^GSPC']-df1['^GSPC'].shift(1)).dropna()

# %%
plt.figure(figsize =(10,4))
plt.plot(first_diffs_sp500, color = '#2980B9',linewidth = 1, label = 'first_diffs_sp500')
plt.title("first_diffs_sp500")
# Out:
# Text(0.5, 1.0, 'first_diffs_sp500')

# %%
#stationary first diff sp 500
perform_adf_test(first_diffs_sp500)
# Out:
# ADF stats: -10.912581
# p-value: 0.000000

# %%
plt.figure(figsize =(12,10)) 
plt.subplot(221)
plot_pacf(first_diffs_sp500,ax=plt.gca());
plt.subplot(222)
plot_acf(first_diffs_sp500,ax=plt.gca());
# Out:
# /root/.local/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
#modeling SP500 first difference
#model=ARMA(first_diffs_sp500,order=(1,0,1))

# %%
#model_fit=model.fit()

# %%
#prediction_info=model_fit.forecast(21)

#predictions = prediction_info[0]
#lower_bound = prediction_info[2][:,0]
#upper_bound = prediction_info[2][:,1]

# %%
#predictions,lower_bound,upper_bound

# %%
#plt.figure(figsize=(20,10))
#plt.plot(first_diffs_sp500.reset_index().drop("Date",axis=1))
#plt.plot(np.arange(len(first_diffs_sp500)+1,len(first_diffs_sp500)+22),predictions,color='g')
#plt.fill_between(np.arange(len(first_diffs_sp500)+1,len(first_diffs_sp500)+22),lower_bound,upper_bound,color='g',alpha=0.1)

# %%
def undo_transformations(predictions, series):
    first_pred = series.iloc[-1]+predictions[0]
    orig_predictions =[first_pred]
    
    for i in range(len(predictions[1:])):
        next_pred = orig_predictions[-1]+predictions[i+1]
        orig_predictions.append(next_pred)
    
    return np.array(orig_predictions).flatten()

# %%
#orig_predictions= undo_transformations(predictions,df1['^GSPC'] )
#orig_lower_bound = undo_transformations(lower_bound, df1['^GSPC'])
#orig_upper_bound = undo_transformations(upper_bound, df1['^GSPC'])

# %%
#plt.figure(figsize=(20,10))
#plt.plot(df1['^GSPC'].reset_index().drop("Date",axis=1))
#plt.plot(np.arange(len(df1['^GSPC'])+1,len(df1['^GSPC'])+22),orig_predictions,color='g')
#plt.fill_between(np.arange(len(df1['^GSPC'])+1,len(df1['^GSPC'])+22),orig_lower_bound,orig_upper_bound,color='g',alpha=0.1)
#plt.title('SP500')

# %%
vix_df.describe()
# Out:
#                VIX           M1           M2        VIX3M          SPX
# count  1540.000000  1540.000000  1540.000000  1540.000000  1540.000000
# mean     18.165883    18.823198    19.800684    20.233727  3043.116297
# std       8.295589     7.218123     6.531843     7.347128   756.471780
# min       9.110000     9.880000    11.300000    11.920000  1978.350000
# 25%      12.737500    14.100000    15.317500    15.220000  2472.445000
# 50%      16.010000    16.800000    17.665000    17.880000  2838.335000
# 75%      21.232500    21.410000    22.662500    23.205000  3401.027500
# max      82.690000    72.600000    60.750000    72.980000  4796.560100

# %%
vix_df['after_1m'] = vix_df['SPX'].shift(-21)
vix_df['after_1w'] = vix_df['SPX'].shift(-5)

# %%
vix_df['rolling 1m return'] = (vix_df['after_1m']-vix_df['SPX'])/vix_df['SPX'] 
vix_df['rolling 1w return'] = (vix_df['after_1w']-vix_df['SPX'])/vix_df['SPX']

# %%
vix_df
# Out:
#               VIX     M1     M2  VIX3M        SPX  after_1m  after_1w  \
# Date
# 2016-03-01  17.70  19.40  20.30  20.28  1978.3500   2059.74   1979.26
# 2016-03-02  17.09  19.30  20.25  19.92  1986.4500   2072.78   1989.26
# 2016-03-03  16.70  18.35  19.50  19.49  1993.4000   2066.13   1989.57
# 2016-03-04  16.86  18.95  20.00  19.63  1999.9900   2045.17   2022.19
# 2016-03-07  17.35  18.60  19.80  19.90  2001.7600   2066.66   2019.64
# ...           ...    ...    ...    ...        ...       ...       ...
# 2022-04-04  18.57  21.00  23.21  23.03  4582.6401       NaN       NaN
# 2022-04-05  21.03  22.85  24.55  24.90  4525.1201       NaN       NaN
# 2022-04-06  22.10  23.95  25.53  25.80  4481.1499       NaN       NaN
# 2022-04-07  21.55  22.72  24.62  25.23  4500.2100       NaN       NaN
# 2022-04-08  21.16  22.60  24.60  25.17  4488.2798       NaN       NaN
#
#             rolling 1m return  rolling 1w return
# Date
# 2016-03-01           0.041140           0.000460
# 2016-03-02           0.043459           0.001415
# 2016-03-03           0.036485          -0.001921
# 2016-03-04           0.022590           0.011100
# 2016-03-07           0.032421           0.008932
# ...                       ...                ...
# 2022-04-04                NaN                NaN
# 2022-04-05                NaN                NaN
# 2022-04-06                NaN                NaN
# 2022-04-07                NaN                NaN
# 2022-04-08                NaN                NaN
#
# [1540 rows x 9 columns]

# %%
vix_df['rolling 1m return'].describe(),vix_df['rolling 1w return'].describe()
# Out:
# (count    1519.000000
#  mean        0.012106
#  std         0.045058
#  min        -0.329668
#  25%        -0.004360
#  50%         0.017670
#  75%         0.034303
#  max         0.251144
#  Name: rolling 1m return, dtype: float64, count    1535.000000
#  mean        0.002935
#  std         0.022867
#  min        -0.179666
#  25%        -0.005569
#  50%         0.004536
#  75%         0.014059
#  max         0.173974
#  Name: rolling 1w return, dtype: float64)

# %%
plt.hist(vix_df['rolling 1m return'], bins='auto')  # arguments are passed to np.histogram
plt.show()

# %%
skew(vix_df['rolling 1m return'].dropna(), axis=0, bias=True),kurtosis(vix_df['rolling 1m return'].dropna(), axis=0, bias=True),skew(vix_df['rolling 1w return'].dropna(), axis=0, bias=True),kurtosis(vix_df['rolling 1w return'].dropna(), axis=0, bias=True)
# Out:
# (-1.859928220326088,
#  12.279282722779598,
#  -0.9843621181296841,
#  10.949594436085409)

# %%
plt.hist(vix_df['rolling 1w return'], bins='auto')  # arguments are passed to np.histogram
plt.show()

# %%
perform_adf_test(vix_df['rolling 1w return'].dropna()),perform_adf_test(vix_df['rolling 1m return'].dropna())
# Out:
# ADF stats: -8.786121
# p-value: 0.000000
# ADF stats: -5.550460
# p-value: 0.000002
# (None, None)

# %%
vix_df["c0"]=vix_df["M1"]/vix_df["VIX"]-1
vix_df["c1"]=vix_df["M2"]/vix_df["M1"]-1
vix_df["c2"]=vix_df["VIX3M"]/vix_df["M2"]-1
vix_df["SP500 return"]=np.log(vix_df['SPX'])-np.log(vix_df['SPX']).shift(1)

# %%
vix_df
4488.2798/1978.3500
# Out:
# 2.2686985619329243

# %%
# np.cumprod(1 + vix_df['log_returns'].dropna().values) - 1

# %%
rho = vix_df.corr()
pval = vix_df.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(4).astype(str) + p
# Out:
#                        VIX       M1       M2    VIX3M      SPX after_1m  \
# VIX                    1.0   0.9789   0.9304   0.9699   0.2532    0.297
# M1                  0.9789      1.0   0.9773   0.9891    0.318   0.3589
# M2                  0.9304   0.9773      1.0   0.9865   0.4054   0.4454
# VIX3M               0.9699   0.9891   0.9865      1.0   0.3639   0.4066
# SPX                 0.2532    0.318   0.4054   0.3639      1.0   0.9817
# after_1m             0.297   0.3589   0.4454   0.4066   0.9817      1.0
# after_1w            0.2602   0.3255   0.4135   0.3722   0.9955   0.9856
# rolling 1m return   0.3134   0.3239   0.3135   0.3217  -0.0825   0.1056
# rolling 1w return   0.0919   0.1054   0.1184   0.1193  -0.0405   0.0354
# c0                 -0.5934   -0.451  -0.3695  -0.4677  -0.0386  -0.0698
# c1                 -0.6102   -0.545  -0.3829  -0.4608   0.0695   0.0595
# c2                  0.5787   0.4467   0.3351   0.4717   0.0321   0.0549
# SP500 return       -0.1614  -0.1213  -0.0864  -0.1134   0.0238   0.0137
#
#                   after_1w rolling 1m return rolling 1w return       c0  \
# VIX                 0.2602            0.3134            0.0919  -0.5934
# M1                  0.3255            0.3239            0.1054   -0.451
# M2                  0.4135            0.3135            0.1184  -0.3695
# VIX3M               0.3722            0.3217            0.1193  -0.4677
# SPX                 0.9955           -0.0825           -0.0405  -0.0386
# after_1m            0.9856            0.1056            0.0354  -0.0698
# after_1w               1.0           -0.0379            0.0522  -0.0425
# rolling 1m return  -0.0379               1.0              0.48  -0.0998
# rolling 1w return   0.0522              0.48               1.0  -0.0237
# c0                 -0.0425           -0.0998           -0.0237      1.0
# c1                  0.0665            -0.123           -0.0234   0.5629
# c2                  0.0347            0.1094            0.0315   -0.822
# SP500 return        0.0221           -0.0439           -0.0413   0.2071
#
#                         c1       c2 SP500 return
# VIX                -0.6102   0.5787      -0.1614
# M1                  -0.545   0.4467      -0.1213
# M2                 -0.3829   0.3351      -0.0864
# VIX3M              -0.4608   0.4717      -0.1134
# SPX                 0.0695   0.0321       0.0238
# after_1m            0.0595   0.0549       0.0137
# after_1w            0.0665   0.0347       0.0221
# rolling 1m return   -0.123   0.1094      -0.0439
# rolling 1w return  -0.0234   0.0315      -0.0413
# c0                  0.5629   -0.822       0.2071
# c1                     1.0  -0.6224       0.1651
# c2                 -0.6224      1.0      -0.1823
# SP500 return        0.1651  -0.1823          1.0

# %%
before_2020=vix_df[:'2020-1-1']
after_2020=vix_df['2020-1-1':]

# %%
before_2020.describe()
# Out:
#               VIX          M1          M2       VIX3M          SPX  \
# count  967.000000  967.000000  967.000000  967.000000   967.000000
# mean    14.399928   15.157844   16.063922   16.244488  2576.528262
# std      3.828107    2.994033    2.420384    2.736205   313.400672
# min      9.110000    9.880000   11.300000   11.920000  1978.350000
# 25%     11.805000   12.900000   14.255000   14.520000  2328.600000
# 50%     13.430000   14.800000   16.210000   15.830000  2636.780000
# 75%     16.020000   16.720000   17.600000   17.740000  2824.020000
# max     37.320000   33.200000   27.950000   28.840000  3240.020000
#
#           after_1m     after_1w  rolling 1m return  rolling 1w return  \
# count   967.000000   967.000000         967.000000         967.000000
# mean   2603.848872  2583.011468           0.011027           0.002662
# std     318.515577   314.210290           0.030171           0.016349
# min    2000.540000  1979.260000          -0.113135          -0.085394
# 25%    2357.095000  2343.085000          -0.004317          -0.004130
# 50%    2651.070000  2639.440000           0.015382           0.003874
# 75%    2845.405000  2832.755000           0.030616           0.012052
# max    3329.620100  3257.850100           0.133410           0.067598
#
#                c0          c1          c2  SP500 return
# count  967.000000  967.000000  967.000000    966.000000
# mean     0.068682    0.069114    0.010173      0.000508
# std      0.081336    0.064977    0.046361      0.007802
# min     -0.280566   -0.248619   -0.189624     -0.041843
# 25%      0.016890    0.028723   -0.018358     -0.002253
# 50%      0.069246    0.073002    0.006936      0.000618
# 75%      0.122218    0.112475    0.033596      0.004445
# max      0.315208    0.282787    0.265278      0.048403

# %%
after_2020.describe()
# Out:
#               VIX          M1          M2       VIX3M          SPX  \
# count  573.000000  573.000000  573.000000  573.000000   573.000000
# mean    24.521344   25.008883   26.106876   26.966003  3830.534501
# std      9.796349    8.000050    6.438604    7.764469   620.195796
# min     12.100000   12.550000   14.940000   14.410000  2237.399900
# 25%     18.040000   19.730000   21.650000   21.830000  3320.790000
# 50%     22.210000   23.390000   25.210000   25.690000  3886.830100
# 75%     27.750000   28.250000   29.670000   30.270000  4395.640100
# max     82.690000   72.600000   60.750000   72.980000  4796.560100
#
#           after_1m     after_1w  rolling 1m return  rolling 1w return  \
# count   552.000000   568.000000         552.000000         568.000000
# mean   3851.547118  3835.681442           0.013997           0.003398
# std     622.250809   620.477899           0.063180           0.030966
# min    2237.399900  2237.399900          -0.329668          -0.179666
# 25%    3350.749975  3327.755000          -0.004379          -0.008472
# 50%    3914.715000  3900.315100           0.022381           0.006073
# 75%    4401.512475  4398.394875           0.044737           0.018204
# max    4796.560100  4796.560100           0.251144           0.173974
#
#                c0          c1          c2  SP500 return
# count  573.000000  573.000000  573.000000    573.000000
# mean     0.041767    0.061374    0.026688      0.000574
# std      0.083181    0.073829    0.054719      0.016146
# min     -0.338070   -0.212189   -0.074504     -0.127652
# 25%     -0.000395    0.023599   -0.009969     -0.005327
# 50%      0.043557    0.074232    0.017577      0.001474
# 75%      0.100054    0.105809    0.049269      0.008058
# max      0.247256    0.230226    0.296269      0.089683

# %%
rho = before_2020.corr()
pval = before_2020.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(4).astype(str) + p
# Out:
#                        VIX       M1       M2    VIX3M      SPX after_1m  \
# VIX                    1.0   0.9604   0.8768   0.9586   0.0685   0.1075
# M1                  0.9604      1.0   0.9488   0.9652   0.0361    0.073
# M2                  0.8768   0.9488      1.0   0.9537  -0.0354  -0.0008
# VIX3M               0.9586   0.9652   0.9537      1.0  -0.0203   0.0145
# SPX                 0.0685   0.0361  -0.0354  -0.0203      1.0   0.9672
# after_1m            0.1075    0.073  -0.0008   0.0145   0.9672      1.0
# after_1w            0.0841   0.0502  -0.0225  -0.0065   0.9904   0.9741
# rolling 1m return   0.1734   0.1617   0.1452   0.1522  -0.1154   0.1395
# rolling 1w return   0.1268   0.1139   0.1024   0.1126  -0.0735   0.0436
# c0                  -0.743  -0.5511   -0.449   -0.638  -0.1516  -0.1752
# c1                 -0.7523  -0.7283  -0.4895  -0.6174  -0.1962  -0.2168
# c2                  0.5356   0.3415    0.153   0.4391   0.0365   0.0459
# SP500 return       -0.2559  -0.2036  -0.1583  -0.2021   0.0276   0.0143
#
#                   after_1w rolling 1m return rolling 1w return       c0  \
# VIX                 0.0841            0.1734            0.1268   -0.743
# M1                  0.0502            0.1617            0.1139  -0.5511
# M2                 -0.0225            0.1452            0.1024   -0.449
# VIX3M              -0.0065            0.1522            0.1126   -0.638
# SPX                 0.9904           -0.1154           -0.0735  -0.1516
# after_1m            0.9741            0.1395            0.0436  -0.1752
# after_1w               1.0           -0.0513            0.0642  -0.1605
# rolling 1m return  -0.0513               1.0             0.461  -0.1123
# rolling 1w return   0.0642             0.461               1.0  -0.0786
# c0                 -0.1605           -0.1123           -0.0786      1.0
# c1                 -0.2035           -0.1088           -0.0657   0.5332
# c2                  0.0411            0.0581            0.0475  -0.7892
# SP500 return        0.0198           -0.0572           -0.0635   0.2527
#
#                         c1       c2 SP500 return
# VIX                -0.7523   0.5356      -0.2559
# M1                 -0.7283   0.3415      -0.2036
# M2                 -0.4895    0.153      -0.1583
# VIX3M              -0.6174   0.4391      -0.2021
# SPX                -0.1962   0.0365       0.0276
# after_1m           -0.2168   0.0459       0.0143
# after_1w           -0.2035   0.0411       0.0198
# rolling 1m return  -0.1088   0.0581      -0.0572
# rolling 1w return  -0.0657   0.0475      -0.0635
# c0                  0.5332  -0.7892       0.2527
# c1                     1.0  -0.5689        0.205
# c2                 -0.5689      1.0      -0.2054
# SP500 return         0.205  -0.2054          1.0

# %%
rho = after_2020.corr()
pval = after_2020.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(4).astype(str) + p
# Out:
#                        VIX       M1       M2    VIX3M      SPX after_1m  \
# VIX                    1.0   0.9748   0.9193   0.9707  -0.6332  -0.5183
# M1                  0.9748      1.0   0.9732   0.9875   -0.636  -0.5118
# M2                  0.9193   0.9732      1.0   0.9798  -0.6227  -0.4822
# VIX3M               0.9707   0.9875   0.9798      1.0  -0.6201  -0.4842
# SPX                -0.6332   -0.636  -0.6227  -0.6201      1.0   0.9417
# after_1m           -0.5183  -0.5118  -0.4822  -0.4842   0.9417      1.0
# after_1w           -0.6198  -0.6178  -0.5977  -0.5971   0.9862   0.9542
# rolling 1m return   0.4284   0.4791   0.5234   0.5042  -0.2054   0.1308
# rolling 1w return   0.0953   0.1328   0.1813   0.1686   -0.095   0.0522
# c0                 -0.6597  -0.5015  -0.4104  -0.5361   0.4116   0.3671
# c1                 -0.7846   -0.741   -0.593  -0.6738   0.4924   0.4748
# c2                  0.7153   0.5794   0.4617   0.6194  -0.3136  -0.2695
# SP500 return       -0.1857   -0.153  -0.1252  -0.1533   0.0396   0.0269
#
#                   after_1w rolling 1m return rolling 1w return       c0  \
# VIX                -0.6198            0.4284            0.0953  -0.6597
# M1                 -0.6178            0.4791            0.1328  -0.5015
# M2                 -0.5977            0.5234            0.1813  -0.4104
# VIX3M              -0.5971            0.5042            0.1686  -0.5361
# SPX                 0.9862           -0.2054            -0.095   0.4116
# after_1m            0.9542            0.1308            0.0522   0.3671
# after_1w               1.0           -0.1277            0.0674   0.4124
# rolling 1m return  -0.1277               1.0            0.4891  -0.0937
# rolling 1w return   0.0674            0.4891               1.0   0.0267
# c0                  0.4124           -0.0937            0.0267      1.0
# c1                  0.4931           -0.1401            0.0102    0.606
# c2                  -0.311             0.146             0.017  -0.8619
# SP500 return        0.0367           -0.0386           -0.0318   0.1996
#
#                         c1       c2 SP500 return
# VIX                -0.7846   0.7153      -0.1857
# M1                  -0.741   0.5794       -0.153
# M2                  -0.593   0.4617      -0.1252
# VIX3M              -0.6738   0.6194      -0.1533
# SPX                 0.4924  -0.3136       0.0396
# after_1m            0.4748  -0.2695       0.0269
# after_1w            0.4931   -0.311       0.0367
# rolling 1m return  -0.1401    0.146      -0.0386
# rolling 1w return   0.0102    0.017      -0.0318
# c0                   0.606  -0.8619       0.1996
# c1                     1.0  -0.6904       0.1497
# c2                 -0.6904      1.0      -0.1831
# SP500 return        0.1497  -0.1831          1.0

# %%
#label buy and sell signals
#1 buy, 0 hold, -1 sell, threshold +-1%
signal = []
for row in vix_df['rolling 1m return']:
    if row < -0.03 :    signal.append(-1)  
    elif row< 0.03: signal.append(0)
    else:           signal.append(1)

vix_df["signal"]=signal

# %%
#label buy and sell signals
#1 buy, 0 hold, -1 sell, threshold +-1%
signal_weekly = []
for row in vix_df['rolling 1w return']:
    if row < -0.03 :    signal_weekly.append(-1)  
    elif row< 0.03: signal_weekly.append(0)
    else:           signal_weekly.append(1)

vix_df["signal_weekly"]=signal_weekly

# %%
vix_df['rolling 1w return'].isna().sum(),vix_df['rolling 1m return'].isna().sum()
# Out:
# (5, 21)

# %%
#plot rolling returns distribution
plt.figure(figsize =(12,10)) 
plt.subplot(221)
plt.hist(vix_df['signal'], bins='auto' )  # arguments are passed to np.histogram
plt.title("Rolling Monthtly Signal  - 1 Month")
plt.subplot(222)
plt.hist(vix_df['signal_weekly'], bins='auto')  # arguments are passed to np.histogram
plt.title("Rolling weekly Signal - 1 week")
plt.show()

# %%
# #plot rolling returns distribution
# plt.hist(vix_df['signal'], bins='auto')  # arguments are passed to np.histogram
# plt.show()

# %%
# #plot rolling returns distribution
# plt.hist(vix_df['signal_weekly'], bins='auto')  # arguments are passed to np.histogram
# plt.show()

# %%
percentiles = [15,20,50,80,85]
rolling_1w =vix_df['rolling 1w return'].dropna()
rolling_1m =vix_df['rolling 1m return'].dropna()

percentile_values_return =np.percentile(rolling_1w,percentiles)
percentile_values_return_1m =np.percentile(rolling_1m,percentiles)

percentile_values_return,percentile_values_return_1m
# Out:
# (array([-0.01314716, -0.00914277,  0.00453623,  0.01629502,  0.01934376]),
#  array([-0.01948141, -0.0106913 ,  0.01767001,  0.03822989,  0.0436796 ]))

# %%
#contangos
contangos_c0= vix_df.loc[vix_df['c0'] >0]
contangos_c1= vix_df.loc[vix_df['c1'] >0]
contangos_c2= vix_df.loc[vix_df['c2'] >0]
#backwardation
back_c0= vix_df.loc[vix_df['c0'] <=0]
back_c1= vix_df.loc[vix_df['c1'] <=0]
back_c2= vix_df.loc[vix_df['c2'] <=0]

# %%
rho = contangos_c0.corr()
pval = contangos_c0.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(4).astype(str) + p
# Out:
#                        VIX       M1       M2    VIX3M      SPX after_1m  \
# VIX                    1.0   0.9862   0.9634   0.9791   0.4905   0.5037
# M1                  0.9862      1.0   0.9851   0.9865   0.5108   0.5192
# M2                  0.9634   0.9851      1.0   0.9929   0.5484   0.5572
# VIX3M               0.9791   0.9865   0.9929      1.0   0.5499    0.561
# SPX                 0.4905   0.5108   0.5484   0.5499      1.0   0.9859
# after_1m            0.5037   0.5192   0.5572    0.561   0.9859      1.0
# after_1w             0.492   0.5127   0.5498    0.551   0.9974   0.9882
# rolling 1m return    0.181   0.1699   0.1548   0.1645  -0.0981    0.067
# rolling 1w return   0.0484   0.0545   0.0496    0.047  -0.0586  -0.0083
# c0                 -0.3707  -0.2205  -0.1845  -0.2619  -0.0917  -0.1177
# c1                  -0.381  -0.3512  -0.1943  -0.2309   0.0096   0.0208
# c2                   0.234   0.1224   0.0643   0.1779    0.102   0.1154
# SP500 return        0.0588   0.0672   0.0675   0.0629   0.0435   0.0402
# signal              0.2415   0.2247    0.201    0.211  -0.0377    0.042
# signal_weekly       0.0623   0.0713   0.0739   0.0747  -0.0081  -0.0154
#
#                   after_1w rolling 1m return rolling 1w return       c0  \
# VIX                  0.492             0.181            0.0484  -0.3707
# M1                  0.5127            0.1699            0.0545  -0.2205
# M2                  0.5498            0.1548            0.0496  -0.1845
# VIX3M                0.551            0.1645             0.047  -0.2619
# SPX                 0.9974           -0.0981           -0.0586  -0.0917
# after_1m            0.9882             0.067           -0.0083  -0.1177
# after_1w               1.0           -0.0696            0.0119  -0.0912
# rolling 1m return  -0.0696               1.0            0.4043  -0.0831
# rolling 1w return   0.0119            0.4043               1.0   0.0065
# c0                 -0.0912           -0.0831            0.0065      1.0
# c1                  0.0074            -0.078           -0.0322   0.2305
# c2                  0.0988            0.0759           -0.0121  -0.6942
# SP500 return        0.0497           -0.0059            0.0013   0.0326
# signal             -0.0231            0.7722            0.3646  -0.1391
# signal_weekly       0.0102             0.262            0.6783   0.0269
#
#                         c1       c2 SP500 return   signal signal_weekly
# VIX                 -0.381    0.234       0.0588   0.2415        0.0623
# M1                 -0.3512   0.1224       0.0672   0.2247        0.0713
# M2                 -0.1943   0.0643       0.0675    0.201        0.0739
# VIX3M              -0.2309   0.1779       0.0629    0.211        0.0747
# SPX                 0.0096    0.102       0.0435  -0.0377       -0.0081
# after_1m            0.0208   0.1154       0.0402    0.042       -0.0154
# after_1w            0.0074   0.0988       0.0497  -0.0231        0.0102
# rolling 1m return   -0.078   0.0759      -0.0059   0.7722         0.262
# rolling 1w return  -0.0322  -0.0121       0.0013   0.3646        0.6783
# c0                  0.2305  -0.6942       0.0326  -0.1391        0.0269
# c1                     1.0  -0.3022      -0.0037  -0.1348        0.0163
# c2                 -0.3022      1.0      -0.0362   0.0783        0.0018
# SP500 return       -0.0037  -0.0362          1.0    0.009       -0.0695
# signal             -0.1348   0.0783        0.009      1.0        0.2262
# signal_weekly       0.0163   0.0018      -0.0695   0.2262           1.0

# %%
rho = contangos_c1.corr()
pval = contangos_c1.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(3).astype(str) + p
# Out:
#                          VIX         M1         M2      VIX3M        SPX  \
# VIX                   1.0***    0.98***   0.963***   0.979***   0.531***
# M1                   0.98***     1.0***   0.988***   0.986***   0.547***
# M2                  0.963***   0.988***     1.0***   0.992***   0.569***
# VIX3M               0.979***   0.986***   0.992***     1.0***    0.58***
# SPX                 0.531***   0.547***   0.569***    0.58***     1.0***
# after_1m            0.549***   0.559***   0.582***   0.595***   0.985***
# after_1w            0.538***   0.554***   0.575***   0.586***   0.997***
# rolling 1m return   0.178***   0.164***   0.156***   0.164***   -0.068**
# rolling 1w return   0.135***    0.13***   0.113***   0.119***      -0.04
# c0                  -0.42***  -0.243***  -0.217***    -0.3***  -0.136***
# c1                 -0.305***   -0.28***  -0.135***  -0.164***      -0.01
# c2                  0.234***   0.099***     0.06**   0.178***   0.154***
# SP500 return          -0.004      0.025      0.032      0.019      0.006
# signal              0.244***    0.22***   0.201***   0.211***     -0.011
# signal_weekly       0.144***   0.143***   0.132***    0.14***      0.004
#
#                     after_1m   after_1w rolling 1m return rolling 1w return  \
# VIX                 0.549***   0.538***          0.178***          0.135***
# M1                  0.559***   0.554***          0.164***           0.13***
# M2                  0.582***   0.575***          0.156***          0.113***
# VIX3M               0.595***   0.586***          0.164***          0.119***
# SPX                 0.985***   0.997***          -0.068**             -0.04
# after_1m              1.0***   0.989***            0.1***             0.034
# after_1w            0.989***     1.0***            -0.034             0.032
# rolling 1m return     0.1***     -0.034            1.0***          0.463***
# rolling 1w return      0.034      0.032          0.463***            1.0***
# c0                 -0.169***  -0.141***         -0.089***            -0.044
# c1                     0.002     -0.016             -0.04         -0.085***
# c2                  0.172***   0.156***           0.062**             0.034
# SP500 return          -0.001       0.01            -0.007             0.001
# signal              0.081***       0.01           0.77***          0.412***
# signal_weekly          0.024      0.029          0.308***           0.69***
#
#                           c0         c1         c2 SP500 return     signal  \
# VIX                 -0.42***  -0.305***   0.234***       -0.004   0.244***
# M1                 -0.243***   -0.28***   0.099***        0.025    0.22***
# M2                 -0.217***  -0.135***     0.06**        0.032   0.201***
# VIX3M                -0.3***  -0.164***   0.178***        0.019   0.211***
# SPX                -0.136***      -0.01   0.154***        0.006     -0.011
# after_1m           -0.169***      0.002   0.172***       -0.001   0.081***
# after_1w           -0.141***     -0.016   0.156***         0.01       0.01
# rolling 1m return  -0.089***      -0.04    0.062**       -0.007    0.77***
# rolling 1w return     -0.044  -0.085***      0.034        0.001   0.412***
# c0                    1.0***   0.195***  -0.715***     0.124***  -0.165***
# c1                  0.195***     1.0***  -0.239***        0.05*   -0.11***
# c2                 -0.715***  -0.239***     1.0***    -0.108***   0.075***
# SP500 return        0.124***      0.05*  -0.108***       1.0***     -0.026
# signal             -0.165***   -0.11***   0.075***       -0.026     1.0***
# signal_weekly         -0.022     -0.036       0.04       -0.027   0.264***
#
#                   signal_weekly
# VIX                    0.144***
# M1                     0.143***
# M2                     0.132***
# VIX3M                   0.14***
# SPX                       0.004
# after_1m                  0.024
# after_1w                  0.029
# rolling 1m return      0.308***
# rolling 1w return       0.69***
# c0                       -0.022
# c1                       -0.036
# c2                         0.04
# SP500 return             -0.027
# signal                 0.264***
# signal_weekly            1.0***

# %%
rho = contangos_c2.corr()
pval = contangos_c2.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(3).astype(str) + p
# Out:
#                          VIX         M1         M2      VIX3M        SPX  \
# VIX                   1.0***   0.983***   0.942***   0.973***   0.187***
# M1                  0.983***     1.0***    0.98***    0.99***   0.245***
# M2                  0.942***    0.98***     1.0***    0.99***   0.347***
# VIX3M               0.973***    0.99***    0.99***     1.0***   0.303***
# SPX                 0.187***   0.245***   0.347***   0.303***     1.0***
# after_1m            0.243***   0.304***   0.409***   0.364***   0.978***
# after_1w            0.196***   0.254***   0.358***   0.315***   0.994***
# rolling 1m return   0.346***   0.372***    0.38***   0.374***  -0.101***
# rolling 1w return   0.089***   0.107***   0.134***   0.128***     -0.046
# c0                 -0.617***  -0.495***  -0.415***  -0.489***       0.02
# c1                 -0.633***  -0.579***  -0.434***  -0.491***    0.16***
# c2                  0.613***   0.494***   0.384***   0.497***     -0.043
# SP500 return       -0.156***  -0.123***  -0.094***  -0.116***      0.005
# signal              0.289***   0.319***    0.34***   0.315***     -0.038
# signal_weekly       0.148***   0.164***   0.185***   0.181***      0.014
#
#                    after_1m  after_1w rolling 1m return rolling 1w return  \
# VIX                0.243***  0.196***          0.346***          0.089***
# M1                 0.304***  0.254***          0.372***          0.107***
# M2                 0.409***  0.358***           0.38***          0.134***
# VIX3M              0.364***  0.315***          0.374***          0.128***
# SPX                0.978***  0.994***         -0.101***            -0.046
# after_1m             1.0***  0.983***          0.106***             0.034
# after_1w           0.983***    1.0***             -0.05             0.06*
# rolling 1m return  0.106***     -0.05            1.0***          0.485***
# rolling 1w return     0.034     0.06*          0.485***            1.0***
# c0                    0.006     0.014            -0.041             0.006
# c1                 0.151***  0.159***         -0.093***              0.01
# c2                   -0.034     -0.04             0.052            -0.007
# SP500 return         -0.002     0.003            -0.046            -0.045
# signal             0.106***    -0.004          0.787***          0.388***
# signal_weekly        0.055*   0.079**           0.39***          0.786***
#
#                           c0         c1         c2 SP500 return    signal  \
# VIX                -0.617***  -0.633***   0.613***    -0.156***  0.289***
# M1                 -0.495***  -0.579***   0.494***    -0.123***  0.319***
# M2                 -0.415***  -0.434***   0.384***    -0.094***   0.34***
# VIX3M              -0.489***  -0.491***   0.497***    -0.116***  0.315***
# SPX                     0.02    0.16***     -0.043        0.005    -0.038
# after_1m               0.006   0.151***     -0.034       -0.002  0.106***
# after_1w               0.014   0.159***      -0.04        0.003    -0.004
# rolling 1m return     -0.041  -0.093***      0.052       -0.046  0.787***
# rolling 1w return      0.006       0.01     -0.007       -0.045  0.388***
# c0                    1.0***   0.619***  -0.797***     0.217***  -0.078**
# c1                  0.619***     1.0***  -0.628***     0.154***  -0.09***
# c2                 -0.797***  -0.628***     1.0***    -0.193***    -0.034
# SP500 return        0.217***   0.154***  -0.193***       1.0***    -0.021
# signal              -0.078**   -0.09***     -0.034       -0.021    1.0***
# signal_weekly         -0.045     -0.023       0.04     -0.071**  0.298***
#
#                   signal_weekly
# VIX                    0.148***
# M1                     0.164***
# M2                     0.185***
# VIX3M                  0.181***
# SPX                       0.014
# after_1m                 0.055*
# after_1w                0.079**
# rolling 1m return       0.39***
# rolling 1w return      0.786***
# c0                       -0.045
# c1                       -0.023
# c2                         0.04
# SP500 return           -0.071**
# signal                 0.298***
# signal_weekly            1.0***

# %%
rho = back_c0.corr()
pval = back_c0.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(3).astype(str) + p
# Out:
#                          VIX         M1         M2      VIX3M        SPX  \
# VIX                   1.0***   0.983***   0.939***   0.973***     -0.032
# M1                  0.983***     1.0***   0.977***   0.988***      0.018
# M2                  0.939***   0.977***     1.0***   0.986***     0.13**
# VIX3M               0.973***   0.988***   0.986***     1.0***      0.079
# SPX                   -0.032      0.018     0.13**      0.079     1.0***
# after_1m               0.073    0.133**   0.249***   0.193***   0.963***
# after_1w              -0.019      0.036   0.154***     0.101*   0.986***
# rolling 1m return   0.447***   0.488***    0.51***   0.496***     -0.068
# rolling 1w return      0.088    0.119**   0.166***   0.158***     -0.023
# c0                 -0.479***  -0.324***  -0.218***  -0.327***   0.231***
# c1                  -0.58***  -0.519***  -0.344***   -0.43***   0.359***
# c2                  0.552***   0.437***   0.316***   0.458***  -0.176***
# SP500 return         -0.111*      -0.09     -0.066     -0.077      0.026
# signal              0.282***   0.332***   0.375***   0.336***      0.067
# signal_weekly        0.139**   0.169***   0.205***   0.195***      0.001
#
#                    after_1m   after_1w rolling 1m return rolling 1w return  \
# VIX                   0.073     -0.019          0.447***             0.088
# M1                  0.133**      0.036          0.488***           0.119**
# M2                 0.249***   0.154***           0.51***          0.166***
# VIX3M              0.193***     0.101*          0.496***          0.158***
# SPX                0.963***   0.986***            -0.068            -0.023
# after_1m             1.0***   0.974***            0.2***           0.115**
# after_1w           0.974***     1.0***             0.024           0.139**
# rolling 1m return    0.2***      0.024            1.0***          0.563***
# rolling 1w return   0.115**    0.139**          0.563***            1.0***
# c0                 0.241***   0.238***             0.035              0.06
# c1                 0.333***   0.365***           -0.097*             0.055
# c2                 -0.17***  -0.175***              0.05             0.001
# SP500 return           0.02      0.018            -0.036            -0.044
# signal              0.28***    0.136**          0.808***          0.433***
# signal_weekly       0.115**    0.137**          0.467***          0.819***
#
#                           c0         c1         c2 SP500 return    signal  \
# VIX                -0.479***   -0.58***   0.552***      -0.111*  0.282***
# M1                 -0.324***  -0.519***   0.437***        -0.09  0.332***
# M2                 -0.218***  -0.344***   0.316***       -0.066  0.375***
# VIX3M              -0.327***   -0.43***   0.458***       -0.077  0.336***
# SPX                 0.231***   0.359***  -0.176***        0.026     0.067
# after_1m            0.241***   0.333***   -0.17***         0.02   0.28***
# after_1w            0.238***   0.365***  -0.175***        0.018   0.136**
# rolling 1m return      0.035    -0.097*       0.05       -0.036  0.808***
# rolling 1w return       0.06      0.055      0.001       -0.044  0.433***
# c0                    1.0***   0.586***  -0.795***       0.14**    0.103*
# c1                  0.586***     1.0***  -0.674***       0.109*     0.005
# c2                 -0.795***  -0.674***     1.0***       -0.078   -0.103*
# SP500 return          0.14**     0.109*     -0.078       1.0***     0.015
# signal                0.103*      0.005    -0.103*        0.015    1.0***
# signal_weekly          0.027     -0.009      0.026       -0.041  0.364***
#
#                   signal_weekly
# VIX                     0.139**
# M1                     0.169***
# M2                     0.205***
# VIX3M                  0.195***
# SPX                       0.001
# after_1m                0.115**
# after_1w                0.137**
# rolling 1m return      0.467***
# rolling 1w return      0.819***
# c0                        0.027
# c1                       -0.009
# c2                        0.026
# SP500 return             -0.041
# signal                 0.364***
# signal_weekly            1.0***

# %%
rho = back_c1.corr()
pval = back_c1.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(3).astype(str) + p
# Out:
#                          VIX         M1         M2      VIX3M       SPX  \
# VIX                   1.0***   0.979***   0.949***   0.977***     0.039
# M1                  0.979***     1.0***   0.987***    0.99***     0.088
# M2                  0.949***   0.987***     1.0***   0.988***   0.159**
# VIX3M               0.977***    0.99***   0.988***     1.0***    0.115*
# SPX                    0.039      0.088    0.159**     0.115*    1.0***
# after_1m            0.176***   0.239***   0.312***   0.264***  0.945***
# after_1w               0.049      0.102   0.181***    0.137**  0.978***
# rolling 1m return   0.483***   0.536***   0.555***   0.537***  -0.129**
# rolling 1w return      0.067       0.09    0.134**    0.132**    -0.061
# c0                 -0.443***  -0.268***  -0.202***  -0.303***     0.12*
# c1                 -0.595***  -0.519***  -0.387***  -0.462***  0.261***
# c2                   0.54***   0.405***   0.329***    0.46***   -0.109*
# SP500 return          -0.12*     -0.091     -0.076     -0.086      0.03
# signal               0.34***   0.407***   0.442***     0.4***     0.026
# signal_weekly          0.106    0.129**    0.165**     0.16**    -0.004
#
#                    after_1m  after_1w rolling 1m return rolling 1w return  \
# VIX                0.176***     0.049          0.483***             0.067
# M1                 0.239***     0.102          0.536***              0.09
# M2                 0.312***  0.181***          0.555***           0.134**
# VIX3M              0.264***   0.137**          0.537***           0.132**
# SPX                0.945***  0.978***          -0.129**            -0.061
# after_1m             1.0***  0.957***          0.199***             0.061
# after_1w           0.957***    1.0***             -0.02           0.147**
# rolling 1m return  0.199***     -0.02            1.0***          0.528***
# rolling 1w return     0.061   0.147**          0.528***            1.0***
# c0                  0.142**    0.127*             0.093             0.036
# c1                 0.209***  0.287***          -0.136**            0.125*
# c2                   -0.101    -0.107             0.034             0.017
# SP500 return          0.016     0.015            -0.043            -0.065
# signal             0.272***     0.102          0.821***          0.379***
# signal_weekly          0.09  0.171***          0.448***          0.828***
#
#                           c0         c1         c2 SP500 return    signal  \
# VIX                -0.443***  -0.595***    0.54***       -0.12*   0.34***
# M1                 -0.268***  -0.519***   0.405***       -0.091  0.407***
# M2                 -0.202***  -0.387***   0.329***       -0.076  0.442***
# VIX3M              -0.303***  -0.462***    0.46***       -0.086    0.4***
# SPX                    0.12*   0.261***    -0.109*         0.03     0.026
# after_1m             0.142**   0.209***     -0.101        0.016  0.272***
# after_1w              0.127*   0.287***     -0.107        0.015     0.102
# rolling 1m return      0.093   -0.136**      0.034       -0.043  0.821***
# rolling 1w return      0.036     0.125*      0.017       -0.065  0.379***
# c0                    1.0***   0.508***  -0.792***     0.175***    0.15**
# c1                  0.508***     1.0***  -0.632***        0.073     -0.05
# c2                 -0.792***  -0.632***     1.0***       -0.083    -0.088
# SP500 return        0.175***      0.073     -0.083       1.0***     0.037
# signal                0.15**      -0.05     -0.088        0.037    1.0***
# signal_weekly          0.005      0.078      0.035       -0.086  0.329***
#
#                   signal_weekly
# VIX                       0.106
# M1                      0.129**
# M2                      0.165**
# VIX3M                    0.16**
# SPX                      -0.004
# after_1m                   0.09
# after_1w               0.171***
# rolling 1m return      0.448***
# rolling 1w return      0.828***
# c0                        0.005
# c1                        0.078
# c2                        0.035
# SP500 return             -0.086
# signal                 0.329***
# signal_weekly            1.0***

# %%
rho = back_c2.corr()
pval = back_c2.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [0.01,0.05,0.1] if x<=t]))
rho.round(3).astype(str) + p
# Out:
#                          VIX         M1         M2     VIX3M       SPX  \
# VIX                   1.0***    0.98***   0.967***  0.969***   0.53***
# M1                   0.98***     1.0***   0.987***  0.984***  0.556***
# M2                  0.967***   0.987***     1.0***  0.996***  0.555***
# VIX3M               0.969***   0.984***   0.996***    1.0***  0.566***
# SPX                  0.53***   0.556***   0.555***  0.566***    1.0***
# after_1m             0.52***    0.54***   0.539***  0.551***  0.988***
# after_1w            0.532***   0.559***   0.556***  0.567***  0.998***
# rolling 1m return     0.069*      0.054      0.035     0.041    -0.066
# rolling 1w return      0.041       0.05      0.029     0.032    -0.038
# c0                 -0.343***  -0.163***  -0.167***   -0.2***   -0.078*
# c1                  -0.17***   -0.18***     -0.027    -0.037  -0.084**
# c2                    0.09**      0.026      0.014   0.097**  0.142***
# SP500 return          -0.023      0.015      0.033     0.039  0.116***
# signal               0.085**     0.078*      0.054     0.058     0.013
# signal_weekly          0.006      0.027      0.011     0.016    -0.057
#
#                     after_1m  after_1w rolling 1m return rolling 1w return  \
# VIX                  0.52***  0.532***            0.069*             0.041
# M1                   0.54***  0.559***             0.054              0.05
# M2                  0.539***  0.556***             0.035             0.029
# VIX3M               0.551***  0.567***             0.041             0.032
# SPX                 0.988***  0.998***            -0.066            -0.038
# after_1m              1.0***   0.99***           0.086**             0.032
# after_1w             0.99***    1.0***            -0.035             0.029
# rolling 1m return    0.086**    -0.035            1.0***          0.457***
# rolling 1w return      0.032     0.029          0.457***            1.0***
# c0                 -0.107***   -0.077*            -0.062             0.008
# c1                    -0.065  -0.091**          -0.084**          -0.086**
# c2                   0.14***   0.14***             0.046             0.022
# SP500 return        0.108***  0.114***             0.023             0.011
# signal                 0.062     0.031           0.75***          0.351***
# signal_weekly         -0.039    -0.029          0.256***          0.626***
#
#                           c0         c1         c2 SP500 return     signal  \
# VIX                -0.343***   -0.17***     0.09**       -0.023    0.085**
# M1                 -0.163***   -0.18***      0.026        0.015     0.078*
# M2                 -0.167***     -0.027      0.014        0.033      0.054
# VIX3M                -0.2***     -0.037    0.097**        0.039      0.058
# SPX                  -0.078*   -0.084**   0.142***     0.116***      0.013
# after_1m           -0.107***     -0.065    0.14***     0.108***      0.062
# after_1w             -0.077*   -0.091**    0.14***     0.114***      0.031
# rolling 1m return     -0.062   -0.084**      0.046        0.023    0.75***
# rolling 1w return      0.008   -0.086**      0.022        0.011   0.351***
# c0                    1.0***     -0.019  -0.458***      0.102**     -0.054
# c1                    -0.019     1.0***   -0.14***        0.066  -0.116***
# c2                 -0.458***   -0.14***     1.0***        0.053      0.021
# SP500 return         0.102**      0.066      0.053       1.0***     0.067*
# signal                -0.054  -0.116***      0.021       0.067*     1.0***
# signal_weekly          0.07*     -0.044      0.043       -0.029   0.208***
#
#                   signal_weekly
# VIX                       0.006
# M1                        0.027
# M2                        0.011
# VIX3M                     0.016
# SPX                      -0.057
# after_1m                 -0.039
# after_1w                 -0.029
# rolling 1m return      0.256***
# rolling 1w return      0.626***
# c0                        0.07*
# c1                       -0.044
# c2                        0.043
# SP500 return             -0.029
# signal                 0.208***
# signal_weekly            1.0***

# %%
cont_back_df = pd.DataFrame(
    {
        "Contagoes e0":contangos_c0['signal'],
        "Contagoes e1": contangos_c1['signal'],
        "Contagoes e2": contangos_c2['signal'],
        "Backwardation e0":back_c0['signal'],
        "Backwardation e1": back_c1['signal'],
        "Backwardation e2": back_c2['signal']
    }
)

# %%
#plot rolling returns distribution
cont_back_df.hist(bins = "auto",layout= [2,3],figsize=(12,6), grid=False,);
plt.suptitle("rolling returns distribution")
plt.show()

# %%
# #plot rolling returns distribution
# plt.hist(contangos_c0['signal'], bins='auto')  # arguments are passed to np.histogram
# plt.show()

# %%
# #plot rolling returns distribution
# plt.hist(contangos_c1['signal'], bins='auto')  # arguments are passed to np.histogram
# plt.show()

# %%
# #plot rolling returns distribution
# plt.hist(contangos_c2['signal'], bins='auto')  # arguments are passed to np.histogram
# plt.show()

# %%
# #plot rolling returns distribution
# plt.hist(back_c0['signal'], bins='auto')  # arguments are passed to np.histogram
# plt.show()

# %%
# plot rolling returns distribution
# plt.hist(back_c1['signal'], bins='auto')  # arguments are passed to np.histogram
# plt.show()

# %%
# #plot rolling returns distribution
# plt.hist(back_c2['signal'], bins='auto')  # arguments are passed to np.histogram
# plt.show()

# %%
#stationary series
perform_adf_test(vix_df.c0),perform_adf_test(vix_df.c1),perform_adf_test(vix_df.c2),perform_adf_test(vix_df['rolling 1m return'].dropna())
# Out:
# ADF stats: -5.038803
# p-value: 0.000019
# ADF stats: -6.228838
# p-value: 0.000000
# ADF stats: -4.632420
# p-value: 0.000113
# ADF stats: -5.550460
# p-value: 0.000002
# (None, None, None, None)

# %%
# plt.title("Contagoes e0,e1 and e2")
nsubplots = 3
color = ["red",'blue',"green"]
fig, ax = plt.subplots(nsubplots, sharex='col', sharey='row',figsize=(10,7))
for data, sub, cl in zip(['c0','c1','c2'],ax.ravel(), color):
  sub.plot(vix_df[data],color = cl)
  sub.set(title = 'Contagoes '+data)

# %%
# plt.figure(figsize=(10,4))
# plt.plot(vix_df['c0'])

# %%
# plt.figure(figsize=(10,4))
# plt.plot(vix_df['c1'])

# %%
# plt.figure(figsize=(10,4))
# plt.plot(vix_df['c2'])

# %%
vix_df=vix_df.dropna()

# %% [markdown]
# # Regression results save as image

# %%
def SaveRegAsImage(modelresults, showNotes = False):
  # fig = plt.figure()
  # split summary results by "Notes" and select the first value in the array, after remove the ending "\n\n" by strip()
  if showNotes == True:
    plt.text(0.01, 0.05, str(modelresults), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
  else:
    plt.text(0.01, 0.05, str(modelresults).split("Notes:")[0].strip("\n\n"), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
  plt.axis('off')
  plt.tight_layout()
  fig.set_size_inches(4,3) 
  #plt.savefig('output.png') # only regquire if you are runing this locally
  return plt.show()

# %% [markdown]
# # Regression Plot

# %%
#LR1
X = vix_df[['VIX','c0','c1','c2','SPX']]
Y = vix_df['rolling 1m return']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      rolling 1m return   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     54.87
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):           1.71e-52
# Time:                        19:48:57   Log-Likelihood:                 2678.3
# No. Observations:                1518   AIC:                            -5345.
# Df Residuals:                    1512   BIC:                            -5313.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0105      0.006     -1.877      0.061      -0.022       0.000
# VIX            0.0029      0.000     15.266      0.000       0.002       0.003
# c0             0.0693      0.023      2.977      0.003       0.024       0.115
# c1             0.0978      0.022      4.376      0.000       0.054       0.142
# c2             0.0077      0.039      0.194      0.846      -0.070       0.085
# SPX         -1.32e-05   1.55e-06     -8.503      0.000   -1.62e-05   -1.02e-05
# ==============================================================================
# Omnibus:                      919.778   Durbin-Watson:                   0.118
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12996.420
# Skew:                          -2.576   Prob(JB):                         0.00
# Kurtosis:                      16.376   Cond. No.                     1.27e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.27e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
SaveRegAsImage(summary)

# %%
#linear model does not work well to predict return in 1 month
X = vix_df[['VIX','M1','M2','VIX3M','c0','c2','SPX']]
Y = vix_df['rolling 1m return']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      rolling 1m return   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     46.30
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):           1.10e-59
# Time:                        19:48:58   Log-Likelihood:                 2699.4
# No. Observations:                1518   AIC:                            -5383.
# Df Residuals:                    1510   BIC:                            -5340.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0192      0.006      3.017      0.003       0.007       0.032
# VIX           -0.0089      0.002     -4.587      0.000      -0.013      -0.005
# M1             0.0070      0.002      3.009      0.003       0.002       0.012
# M2            -0.0219      0.004     -5.791      0.000      -0.029      -0.014
# VIX3M          0.0255      0.004      6.874      0.000       0.018       0.033
# c0            -0.1312      0.040     -3.306      0.001      -0.209      -0.053
# c2            -0.4747      0.085     -5.584      0.000      -0.641      -0.308
# SPX        -1.431e-05   1.74e-06     -8.242      0.000   -1.77e-05   -1.09e-05
# ==============================================================================
# Omnibus:                      908.494   Durbin-Watson:                   0.133
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13561.559
# Skew:                          -2.510   Prob(JB):                         0.00
# Kurtosis:                      16.755   Cond. No.                     2.68e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.68e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
SaveRegAsImage(summary)

# %%
X = vix_df[['VIX','M1','M2','VIX3M','c0','c1','c2']]
Y = vix_df['SPX']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SPX   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     112.3
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):          1.14e-132
# Time:                        19:48:59   Log-Likelihood:                -11869.
# No. Observations:                1518   AIC:                         2.375e+04
# Df Residuals:                    1510   BIC:                         2.380e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1735.9710     98.041     17.707      0.000    1543.661    1928.282
# VIX          -57.1069     28.904     -1.976      0.048    -113.802      -0.411
# M1          -275.3849     50.744     -5.427      0.000    -374.921    -175.849
# M2           351.2156     55.021      6.383      0.000     243.289     459.142
# VIX3M         34.0129     62.057      0.548      0.584     -87.714     155.740
# c0           432.2363    592.543      0.729      0.466    -730.058    1594.531
# c1         -3250.8256    707.785     -4.593      0.000   -4639.172   -1862.479
# c2          3878.1105   1386.391      2.797      0.005    1158.655    6597.566
# ==============================================================================
# Omnibus:                       49.922   Durbin-Watson:                   0.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.618
# Skew:                           0.408   Prob(JB):                     1.68e-11
# Kurtosis:                       2.657   Cond. No.                     3.90e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.9e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
SaveRegAsImage(summary)

# %%
#'M1','M2','c1','c2' explains SPX 0.334
X = vix_df[['M1','M2','c1','c2']]
Y = vix_df['SPX']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SPX   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     189.3
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):          1.21e-131
# Time:                        19:49:00   Log-Likelihood:                -11879.
# No. Observations:                1518   AIC:                         2.377e+04
# Df Residuals:                    1513   BIC:                         2.380e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1829.3327     62.469     29.284      0.000    1706.799    1951.867
# M1          -347.9566     21.460    -16.214      0.000    -390.052    -305.862
# M2           400.5140     21.444     18.677      0.000     358.451     442.577
# c1         -3363.8300    505.922     -6.649      0.000   -4356.212   -2371.448
# c2          2601.6122    412.762      6.303      0.000    1791.965    3411.259
# ==============================================================================
# Omnibus:                       47.463   Durbin-Watson:                   0.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.343
# Skew:                           0.432   Prob(JB):                     1.17e-11
# Kurtosis:                       2.780   Cond. No.                         953.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vix_df_1=vix_df.iloc[1:]

# %%
vix_df_1
# Out:
#               VIX     M1     M2  VIX3M        SPX   after_1m   after_1w  \
# Date
# 2016-03-03  16.70  18.35  19.50  19.49  1993.4000  2066.1300  1989.5700
# 2016-03-04  16.86  18.95  20.00  19.63  1999.9900  2045.1700  2022.1900
# 2016-03-07  17.35  18.60  19.80  19.90  2001.7600  2066.6600  2019.6400
# 2016-03-08  18.67  19.65  20.65  21.04  1979.2600  2041.9100  2015.9300
# 2016-03-09  18.34  19.10  20.15  20.75  1989.2600  2047.6000  2027.2200
# ...           ...    ...    ...    ...        ...        ...        ...
# 2022-03-04  31.98  32.10  30.60  32.34  4328.8701  4582.6401  4204.3101
# 2022-03-07  36.45  34.55  32.69  35.74  4201.0898  4525.1201  4173.1099
# 2022-03-08  35.13  34.14  32.82  35.00  4170.7002  4481.1499  4262.4502
# 2022-03-09  32.45  32.00  31.38  33.06  4277.8799  4500.2100  4357.8599
# 2022-03-10  30.23  30.30  29.93  31.52  4259.5200  4488.2798  4411.6699
#
#             rolling 1m return  rolling 1w return        c0        c1  \
# Date
# 2016-03-03           0.036485          -0.001921  0.098802  0.062670
# 2016-03-04           0.022590           0.011100  0.123962  0.055409
# 2016-03-07           0.032421           0.008932  0.072046  0.064516
# 2016-03-08           0.031653           0.018527  0.052491  0.050891
# 2016-03-09           0.029327           0.019082  0.041439  0.054974
# ...                       ...                ...       ...       ...
# 2022-03-04           0.058623          -0.028774  0.003752 -0.046729
# 2022-03-07           0.077130          -0.006660 -0.052126 -0.053835
# 2022-03-08           0.074436           0.021999 -0.028181 -0.038664
# 2022-03-09           0.051972           0.018696 -0.013867 -0.019375
# 2022-03-10           0.053706           0.035720  0.002316 -0.012211
#
#                   c2  SP500 return  signal  signal_weekly
# Date
# 2016-03-03 -0.000513      0.003493       1              0
# 2016-03-04 -0.018500      0.003300       0              0
# 2016-03-07  0.005051      0.000885       1              0
# 2016-03-08  0.018886     -0.011304       1              0
# 2016-03-09  0.029777      0.005040       0              0
# ...              ...           ...     ...            ...
# 2022-03-04  0.056863     -0.007966       1              0
# 2022-03-07  0.093301     -0.029963       1              0
# 2022-03-08  0.066423     -0.007260       1              0
# 2022-03-09  0.053537      0.025374       1              0
# 2022-03-10  0.053124     -0.004301       1              1
#
# [1517 rows x 15 columns]

# %%
SaveRegAsImage(summary)

# %%
perform_adf_test(vix_df['VIX']),perform_adf_test(vix_df['M1']),perform_adf_test(vix_df['M2'])
# Out:
# ADF stats: -3.867431
# p-value: 0.002288
# ADF stats: -3.454985
# p-value: 0.009221
# ADF stats: -2.840882
# p-value: 0.052667
# (None, None, None)

# %%
#first regression to determine the spread on spot vix next time period  1
X = vix_df[['c0']][:-1]
y = vix_df['VIX'].shift(-1).dropna()
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIX   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     738.2
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):          9.26e-133
# Time:                        19:49:02   Log-Likelihood:                -5066.1
# No. Observations:                1517   AIC:                         1.014e+04
# Df Residuals:                    1515   BIC:                         1.015e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         21.4276      0.214    100.177      0.000      21.008      21.847
# c0           -57.2427      2.107    -27.170      0.000     -61.375     -53.110
# ==============================================================================
# Omnibus:                      823.844   Durbin-Watson:                   0.284
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8970.948
# Skew:                           2.312   Prob(JB):                         0.00
# Kurtosis:                      13.979   Cond. No.                         12.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
SaveRegAsImage(summary)

# %%
X = vix_df[['c0']][:-1] # 2
y = (vix_df['VIX'].shift(-1)-vix_df['VIX']).dropna()
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIX   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     16.38
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):           5.45e-05
# Time:                        19:49:02   Log-Likelihood:                -3266.5
# No. Observations:                1517   AIC:                             6537.
# Df Residuals:                    1515   BIC:                             6548.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1427      0.065     -2.185      0.029      -0.271      -0.015
# c0             2.6035      0.643      4.047      0.000       1.342       3.865
# ==============================================================================
# Omnibus:                     1221.164   Durbin-Watson:                   2.405
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            84654.275
# Skew:                           3.222   Prob(JB):                         0.00
# Kurtosis:                      39.025   Cond. No.                         12.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
SaveRegAsImage(summary)

# %%
#regression: to determine the spread on spot vix next time period  3
spread= vix_df['M1']-vix_df['VIX']
X = spread[:-1]
y = (vix_df['VIX'].shift(-1)-vix_df['VIX']).dropna()
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIX   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     26.37
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):           3.19e-07
# Time:                        19:49:03   Log-Likelihood:                -3261.6
# No. Observations:                1517   AIC:                             6527.
# Df Residuals:                    1515   BIC:                             6538.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0821      0.056     -1.461      0.144      -0.192       0.028
# 0              0.1425      0.028      5.135      0.000       0.088       0.197
# ==============================================================================
# Omnibus:                     1297.282   Durbin-Watson:                   2.363
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            91046.826
# Skew:                           3.559   Prob(JB):                         0.00
# Kurtosis:                      40.280   Cond. No.                         2.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
SaveRegAsImage(summary)

# %%
SaveRegAsImage(summary)

# %%
#regression: to determine the spread on spot vix next time period 4
spread= vix_df['M1']-vix_df['VIX']
X = spread[:-1]
y = (vix_df['M1'].shift(-1)-vix_df['M1']).dropna()
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     M1   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.2622
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):              0.609
# Time:                        19:49:05   Log-Likelihood:                -2808.9
# No. Observations:                1517   AIC:                             5622.
# Df Residuals:                    1515   BIC:                             5632.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0140      0.042      0.335      0.738      -0.068       0.096
# 0             -0.0105      0.021     -0.512      0.609      -0.051       0.030
# ==============================================================================
# Omnibus:                     1141.717   Durbin-Watson:                   2.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            87616.632
# Skew:                           2.849   Prob(JB):                         0.00
# Kurtosis:                      39.793   Cond. No.                         2.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
SaveRegAsImage(summary)

# %%
#regression: to determine the spread on spot vix next time period 5
spread= vix_df['M1']-vix_df['VIX']
X = spread[:-1]
y = vix_df['VIX'].shift(-1).dropna()
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIX   R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.380
# Method:                 Least Squares   F-statistic:                     930.9
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):          8.70e-160
# Time:                        19:49:06   Log-Likelihood:                -5003.9
# No. Observations:                1517   AIC:                         1.001e+04
# Df Residuals:                    1515   BIC:                         1.002e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         19.8010      0.177    111.679      0.000      19.453      20.149
# 0             -2.6701      0.088    -30.511      0.000      -2.842      -2.498
# ==============================================================================
# Omnibus:                      529.342   Durbin-Watson:                   0.345
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2274.377
# Skew:                           1.623   Prob(JB):                         0.00
# Kurtosis:                       8.044   Cond. No.                         2.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
SaveRegAsImage(summary)

# %%
#regression 2 to determine the spread on future vix next time period 6
spread= vix_df['M1']-vix_df['VIX']
X = spread[:-1]
y = vix_df['M1'].shift(-1).dropna()
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     M1   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     467.1
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):           1.64e-90
# Time:                        19:49:07   Log-Likelihood:                -4948.2
# No. Observations:                1517   AIC:                             9900.
# Df Residuals:                    1515   BIC:                             9911.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         19.8971      0.171    116.421      0.000      19.562      20.232
# 0             -1.8231      0.084    -21.612      0.000      -1.989      -1.658
# ==============================================================================
# Omnibus:                      477.861   Durbin-Watson:                   0.169
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1623.759
# Skew:                           1.542   Prob(JB):                         0.00
# Kurtosis:                       7.022   Cond. No.                         2.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
SaveRegAsImage(summary)

# %%
#plot_acf(vix_df['VIX'])

# %% [markdown]
# # Machine Learning and Analysis

# %%
X = vix_df[['VIX','c0','c1','c2']]
y = vix_df['rolling 1m return']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
regr = linear_model.LinearRegression()

# fit the model to the training data (learn the coefficients)
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regr.intercept_)
print(regr.coef_)
# Out:
# -0.0345939816476859
# [ 0.00222544  0.04765642  0.04500179 -0.00432011]

# %%
X_train.shape,X_test.shape
# Out:
# ((1138, 4), (380, 4))

# %%
y_pred = regr.predict(X_test)

# %%
plt.plot(y_pred)

# %%
from sklearn import metrics
#Mean Absolute Error (MAE) 
print(metrics.mean_absolute_error(y_test, y_pred))
#Mean Squared Error (MSE)
print(metrics.mean_squared_error(y_test, y_pred))
#Root Mean Squared Error (RMSE)
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 0.02843685797800111
# 0.001982061573844393
# 0.04452035010918482

# %%
est = sm.OLS(y_train, X_train)
est2 = est.fit()
print(est2.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      rolling 1m return   R-squared (uncentered):                   0.139
# Model:                            OLS   Adj. R-squared (uncentered):              0.136
# Method:                 Least Squares   F-statistic:                              45.86
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):                    9.53e-36
# Time:                        19:49:09   Log-Likelihood:                          1981.1
# No. Observations:                1138   AIC:                                     -3954.
# Df Residuals:                    1134   BIC:                                     -3934.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# VIX            0.0011      0.000     10.445      0.000       0.001       0.001
# c0            -0.0400      0.023     -1.743      0.082      -0.085       0.005
# c1            -0.0504      0.021     -2.397      0.017      -0.092      -0.009
# c2            -0.1119      0.043     -2.626      0.009      -0.196      -0.028
# ==============================================================================
# Omnibus:                      719.038   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11785.203
# Skew:                          -2.635   Prob(JB):                         0.00
# Kurtosis:                      17.859   Cond. No.                         714.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
SaveRegAsImage(est2.summary())

# %%
# !pip install --user pycaret-ts-alpha;
# !pip install -U pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycaret-ts-alpha in /root/.local/lib/python3.7/site-packages (3.0.0.dev1649017462)
# Requirement already satisfied: numpy~=1.21 in /usr/local/lib/python3.7/dist-packages (from pycaret-ts-alpha) (1.21.6)
# Requirement already satisfied: category-encoders>=2.4.0 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (2.5.1.post0)
# Requirement already satisfied: joblib~=1.0.1 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (1.0.1)
# Requirement already satisfied: pyod>=0.9.8 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (1.0.6)
# Requirement already satisfied: tbats>=1.1.0 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (1.1.1)
# Requirement already satisfied: numba~=0.55.0 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (0.55.2)
# Requirement already satisfied: sktime==0.10.1 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (0.10.1)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pycaret-ts-alpha) (5.5.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (3.5.3)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.7/dist-packages (from pycaret-ts-alpha) (1.5)
# Requirement already satisfied: pandas<1.5.0,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pycaret-ts-alpha) (1.3.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (0.3.7)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from pycaret-ts-alpha) (0.8.1)
# Requirement already satisfied: kaleido>=0.2.1 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (0.2.1)
# Requirement already satisfied: lightgbm>=3.0.0 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (3.3.3)
# Requirement already satisfied: statsmodels>=0.12.1 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (0.13.3)
# Requirement already satisfied: pmdarima>=1.8.0 in /root/.local/lib/python3.7/site-packages (from pycaret-ts-alpha) (2.0.1)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.7/dist-packages (from pycaret-ts-alpha) (7.9.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from pycaret-ts-alpha) (1.0.2)
# Requirement already satisfied: scipy~=1.7.3 in /usr/local/lib/python3.7/dist-packages (from pycaret-ts-alpha) (1.7.3)
# Requirement already satisfied: deprecated>=1.2.13 in /root/.local/lib/python3.7/site-packages (from sktime==0.10.1->pycaret-ts-alpha) (1.2.13)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category-encoders>=2.4.0->pycaret-ts-alpha) (0.5.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.13->sktime==0.10.1->pycaret-ts-alpha) (1.14.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret-ts-alpha) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret-ts-alpha) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret-ts-alpha) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret-ts-alpha) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret-ts-alpha) (5.1.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.5.0->pycaret-ts-alpha) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /root/.local/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=5.5.0->pycaret-ts-alpha) (0.8.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.0.0->pycaret-ts-alpha) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /root/.local/lib/python3.7/site-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.0->pycaret-ts-alpha) (4.1.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /root/.local/lib/python3.7/site-packages (from numba~=0.55.0->pycaret-ts-alpha) (0.38.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.5.0,>=1.3.0->pycaret-ts-alpha) (2022.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret-ts-alpha) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->pycaret-ts-alpha) (8.1.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima>=1.8.0->pycaret-ts-alpha) (0.29.32)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima>=1.8.0->pycaret-ts-alpha) (1.24.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.5.0->pycaret-ts-alpha) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.2->pycaret-ts-alpha) (3.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython>=5.5.0->pycaret-ts-alpha) (0.7.0)

# %%
pip install scikit-plot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-plot in /root/.local/lib/python3.7/site-packages (0.3.7)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.7/dist-packages (from scikit-plot) (1.0.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.7/dist-packages (from scikit-plot) (1.7.3)
# Requirement already satisfied: matplotlib>=1.4.0 in /root/.local/lib/python3.7/site-packages (from scikit-plot) (3.5.3)
# Requirement already satisfied: joblib>=0.10 in /root/.local/lib/python3.7/site-packages (from scikit-plot) (1.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.0->scikit-plot) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /root/.local/lib/python3.7/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.38.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=1.4.0->scikit-plot) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.1.0)

# %%
# #compare models
# import scikit-plot as skplt
# from pycaret.classification import *
# #s = setup(data=y_train, X_train, target= signal)

# %%
from pycaret.classification import *

# %%
train_data_0=vix_df.sample(frac=0.9,random_state=345)
test_data_0 = vix_df.drop(train_data_0.index)
train_data=train_data_0.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1)
test_data=test_data_0.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1)
train_data.reset_index(inplace=True,drop=True)
test_data.reset_index(inplace=True,drop=True)

# %%
X = vix_df[['VIX','c0','c1','c2']]
y = vix_df['rolling 1m return']

# %%
from pycaret.classification import *

# %%
s=setup(data=train_data,target='signal',session_id=	345);
# Out:
# INFO:logs:PyCaret ClassificationExperiment
# INFO:logs:Logging name: clf-default-name
# INFO:logs:ML Usecase: MLUsecase.CLASSIFICATION
# INFO:logs:version 3.0.0
# INFO:logs:Initializing setup()
# INFO:logs:self.USI: f998
# INFO:logs:self.variable_keys: {'memory', '_gpu_n_jobs_param', 'fold_param', 'exp_name_log', 'fold_shuffle_param', '_all_metrics', 'fold_groups_param_full', '_all_models', 'target_param', 'y', 'imputation_classifier', 'display_container', 'variable_keys', 'data', 'imputation_regressor', 'X_test', 'html_param', 'seed', 'fold_groups_param', 'X_train', 'y_train', 'experiment__', 'logging_param', 'fix_imbalance_method_param', 'stratify_param', 'exp_id', 'pipeline', 'fix_imbalance_param', 'n_jobs_param', 'log_plots_param', 'USI', 'X', '_all_models_internal', 'fold_generator', 'y_test', 'master_model_container', '_ml_usecase', 'iterative_imputation_iters_param', '_available_plots', 'idx', 'gpu_param'}
# INFO:logs:Checking environment
# INFO:logs:python_version: 3.7.15
# INFO:logs:python_build: ('default', 'Oct 12 2022 19:14:55')
# INFO:logs:machine: x86_64
# INFO:logs:platform: Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# INFO:logs:Memory: svmem(total=13616361472, available=12592431104, percent=7.5, used=790179840, free=9463885824, active=601563136, inactive=3247349760, buffers=116895744, cached=3245400064, shared=1294336, slab=232755200)
# INFO:logs:Physical Core: 1
# INFO:logs:Logical Core: 2
# INFO:logs:Checking libraries
# INFO:logs:pd==1.3.5
# INFO:logs:numpy==1.21.6
# INFO:logs:sklearn==1.0.2
# INFO:logs:lightgbm==3.3.3
# INFO:logs:xgboost==0.90
# WARNING:logs:catboost not found
# WARNING:logs:mlflow not found
# INFO:logs:Set up data.
# INFO:logs:Set up target column.
# INFO:logs:Assigning column types.
# INFO:logs:Set up train/test split.
# INFO:logs:Set up folding strategy.
# INFO:logs:Preparing preprocessing pipeline...
# INFO:logs:Set up simple imputation.
# INFO:logs:Finished creating preprocessing pipeline.
# INFO:logs:Pipeline: Pipeline(memory=Memory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransfomerWrapper(include=['VIX', 'M1', 'M2', 'VIX3M', 'c0', 'c1', 'c2'], transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransfomerWrapper(include=[], transformer=SimpleImputer(fill_value='constant', strategy='constant')))])
# INFO:logs:Creating final display dataframe.
# INFO:logs:Setup display_container:                Description             Value
# 0               Session id               345
# 1                   Target            signal
# 2              Target type    classification
# 3               Data shape         (1366, 8)
# 4         Train data shape          (956, 8)
# 5          Test data shape          (410, 8)
# 6         Numeric features                 7
# 7               Preprocess              True
# 8          Imputation type            simple
# 9       Numeric imputation              mean
# 10  Categorical imputation          constant
# 11          Fold Generator   StratifiedKFold
# 12             Fold Number                10
# 13                CPU Jobs                -1
# 14          Log Experiment             False
# 15         Experiment Name  clf-default-name
# 16                     USI              f998
# INFO:logs:Preparing display monitor
#                Description             Value
# 0               Session id               345
# 1                   Target            signal
# 2              Target type    classification
# 3               Data shape         (1366, 8)
# 4         Train data shape          (956, 8)
# 5          Test data shape          (410, 8)
# 6         Numeric features                 7
# 7               Preprocess              True
# 8          Imputation type            simple
# 9       Numeric imputation              mean
# 10  Categorical imputation          constant
# 11          Fold Generator   StratifiedKFold
# 12             Fold Number                10
# 13                CPU Jobs                -1
# 14          Log Experiment             False
# 15         Experiment Name  clf-default-name
# 16                     USI              f998
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==0.90
# WARNING:logs:Couldn't import catboost.CatBoostClassifier
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==0.90
# WARNING:logs:Couldn't import catboost.CatBoostClassifier
# INFO:logs:setup() successfully completed in 1.28s...............

# %%
#compare models
model= compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.7018  0.8035  0.5600  0.6868
# et                 Extra Trees Classifier    0.6946  0.8254  0.5688  0.6856
# rf               Random Forest Classifier    0.6841  0.8174  0.5225  0.6649
# gbc          Gradient Boosting Classifier    0.6695  0.7835  0.4960  0.6304
# ada                  Ada Boost Classifier    0.6475  0.6823  0.4772  0.6089
# dt               Decision Tree Classifier    0.6464  0.6879  0.5595  0.6503
# ridge                    Ridge Classifier    0.6455  0.0000  0.4276  0.5681
# lda          Linear Discriminant Analysis    0.6424  0.7096  0.4354  0.5868
# lr                    Logistic Regression    0.6413  0.6986  0.4269  0.5625
# qda       Quadratic Discriminant Analysis    0.6370  0.6956  0.4230  0.6150
# nb                            Naive Bayes    0.6203  0.6959  0.4449  0.5847
# knn                K Neighbors Classifier    0.6130  0.7303  0.4606  0.5914
# svm                   SVM - Linear Kernel    0.5835  0.0000  0.4150  0.5716
# dummy                    Dummy Classifier    0.5826  0.5000  0.3333  0.3395
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.6847  0.4260  0.4347     0.367
# et        0.6806  0.4146  0.4236     0.443
# rf        0.6614  0.3835  0.3944     0.619
# gbc       0.6384  0.3464  0.3590     1.414
# ada       0.6151  0.3023  0.3140     0.260
# dt        0.6469  0.3681  0.3690     0.069
# ridge     0.5809  0.2382  0.2768     0.046
# lda       0.5858  0.2451  0.2738     0.054
# lr        0.5787  0.2331  0.2662     0.824
# qda       0.5663  0.2090  0.2633     0.046
# nb        0.5862  0.2362  0.2500     0.066
# knn       0.5921  0.2511  0.2586     0.158
# svm       0.5268  0.1811  0.2289     0.098
# dummy     0.4290  0.0000  0.0000     0.027
# INFO:logs:master_model_container: 14
# INFO:logs:display_container: 2
# INFO:logs:LGBMClassifier(random_state=345)
# INFO:logs:compare_models() successfully completed......................................

# %%
#creaete Extra Trees Classifier
et_model = create_model('et')
lightgbm_model = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.6875  0.8060  0.5512  0.6782  0.6608  0.3782  0.4020
# 1       0.7396  0.8402  0.6309  0.7351  0.7360  0.5192  0.5208
# 2       0.7188  0.8208  0.5348  0.6841  0.6909  0.4447  0.4588
# 3       0.6875  0.8055  0.5435  0.6729  0.6669  0.3842  0.3983
# 4       0.7083  0.8272  0.5532  0.6894  0.6876  0.4340  0.4421
# 5       0.7083  0.7718  0.5853  0.6963  0.6945  0.4393  0.4483
# 6       0.6632  0.7860  0.4855  0.6293  0.6388  0.3339  0.3414
# 7       0.7158  0.8535  0.5881  0.7049  0.7096  0.4791  0.4799
# 8       0.6842  0.7398  0.5269  0.6519  0.6649  0.4094  0.4124
# 9       0.7053  0.7846  0.6008  0.7255  0.6966  0.4376  0.4435
# Mean    0.7018  0.8035  0.5600  0.6868  0.6847  0.4260  0.4347
# SD      0.0205  0.0323  0.0397  0.0301  0.0263  0.0500  0.0469
# INFO:logs:master_model_container: 16
# INFO:logs:display_container: 4
# INFO:logs:LGBMClassifier(random_state=345)
# INFO:logs:create_model() successfully completed......................................

# %%
plot_model(et_model, plot='auc')
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() successfully completed......................................

# %%
plot_model(lightgbm_model, plot='confusion_matrix')
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() successfully completed......................................

# %%
plot_model(lightgbm_model,plot='feature')
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() successfully completed......................................

# %%
test_data_new_0=vix_df.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1)
#test_data_new=test_data_new_0.reset_index(inplace=True,drop=True)

# %%
test_data_new=test_data_new_0.iloc[:,0:8]

# %%
test_data_new.reset_index(inplace=True,drop=True)

# %%
predictions = predict_model(lightgbm_model, data=test_data_new)
predictions, test_data_new
# Out:
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=LGBMClassifier(random_state=345), probability_threshold=None, encoded_labels=False, raw_score=False, drift_report=False, round=4, verbose=True, ml_usecase=None, display=None, replace_labels_in_column=<function _SupervisedExperiment.predict_model.<locals>.replace_labels_in_column at 0x7f9a0a25f4d0>, self=<pycaret.classification.oop.ClassificationExperiment object at 0x7f9a045dbb50>)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor
# (        VIX     M1     M2  VIX3M        c0        c1        c2  Label   Score
#  0     17.09  19.30  20.25  19.92  0.129315  0.049223 -0.016296      1  0.0757
#  1     16.70  18.35  19.50  19.49  0.098802  0.062670 -0.000513      0  0.0005
#  2     16.86  18.95  20.00  19.63  0.123962  0.055409 -0.018500      0  0.0065
#  3     17.35  18.60  19.80  19.90  0.072046  0.064516  0.005051      1  0.1174
#  4     18.67  19.65  20.65  21.04  0.052491  0.050891  0.018886      1  0.1166
#  ...     ...    ...    ...    ...       ...       ...       ...    ...     ...
#  1513  31.98  32.10  30.60  32.34  0.003752 -0.046729  0.056863      1  0.0749
#  1514  36.45  34.55  32.69  35.74 -0.052126 -0.053835  0.093301      1  0.0578
#  1515  35.13  34.14  32.82  35.00 -0.028181 -0.038664  0.066423      1  0.0114
#  1516  32.45  32.00  31.38  33.06 -0.013867 -0.019375  0.053537      1  0.0323
#  1517  30.23  30.30  29.93  31.52  0.002316 -0.012211  0.053124      1  0.0245
#
#  [1518 rows x 9 columns],
#          VIX     M1     M2  VIX3M        c0        c1        c2  signal
#  0     17.09  19.30  20.25  19.92  0.129315  0.049223 -0.016296       1
#  1     16.70  18.35  19.50  19.49  0.098802  0.062670 -0.000513       1
#  2     16.86  18.95  20.00  19.63  0.123962  0.055409 -0.018500       0
#  3     17.35  18.60  19.80  19.90  0.072046  0.064516  0.005051       1
#  4     18.67  19.65  20.65  21.04  0.052491  0.050891  0.018886       1
#  ...     ...    ...    ...    ...       ...       ...       ...     ...
#  1513  31.98  32.10  30.60  32.34  0.003752 -0.046729  0.056863       1
#  1514  36.45  34.55  32.69  35.74 -0.052126 -0.053835  0.093301       1
#  1515  35.13  34.14  32.82  35.00 -0.028181 -0.038664  0.066423       1
#  1516  32.45  32.00  31.38  33.06 -0.013867 -0.019375  0.053537       1
#  1517  30.23  30.30  29.93  31.52  0.002316 -0.012211  0.053124       1
#
#  [1518 rows x 8 columns])

# %%
save_model(lightgbm_model,'vix_trading_signal_lightgbm')
# Out:
# INFO:logs:Initializing save_model()
# INFO:logs:save_model(model=LGBMClassifier(random_state=345), model_name=vix_trading_signal_lightgbm, prep_pipe_=Pipeline(memory=Memory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransfomerWrapper(include=['VIX', 'M1', 'M2', 'VIX3M', 'c0', 'c1', 'c2'], transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransfomerWrapper(include=[], transformer=SimpleImputer(fill_value='constant', strategy='constant')))]), verbose=True, use_case=MLUsecase.CLASSIFICATION, kwargs={})
# INFO:logs:Adding model into prep_pipe
# INFO:logs:vix_trading_signal_lightgbm.pkl saved in current working directory
# INFO:logs:Pipeline(memory=Memory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransfomerWrapper(include=['VIX', 'M1', 'M2', 'VIX3M', 'c0', 'c1', 'c2'], transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransfomerWrapper(include=[], transformer=SimpleImputer(fill_value='constant', strategy='constant'))),
#                 ['trained_model', LGBMClassifier(random_state=345)]])
# INFO:logs:save_model() successfully completed......................................
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransfomerWrapper(include=['VIX', 'M1', 'M2', 'VIX3M', 'c0', 'c1', 'c2'], transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransfomerWrapper(include=[], transformer=SimpleImputer(fill_value='constant', strategy='constant'))),
#                  ['trained_model', LGBMClassifier(random_state=345)]]),
#  'vix_trading_signal_lightgbm.pkl')

# %% [markdown]
# 2. Machine learning for Regression

# %%
#@title
data=vix_df.drop(columns=['after_1m','after_1w','rolling 1m return','rolling 1w return']).iloc[:,0:8]

# %%
#@title
dataset = data.sample(frac=0.9, random_state=786)
data_unseen = data.drop(dataset.index)

dataset.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

# %%
#@title
dataset
# Out:
#         VIX     M1     M2  VIX3M        SPX        c0        c1        c2
# 0     12.60  14.64  15.60  14.82  2900.4500  0.161905  0.065574 -0.050000
# 1     12.05  12.90  15.15  15.41  2175.4900  0.070539  0.174419  0.017162
# 2     24.46  26.85  29.67  29.71  3271.1201  0.097711  0.105028  0.001348
# 3     16.39  16.61  16.78  17.03  3273.3999  0.013423  0.010235  0.014899
# 4     16.41  18.35  20.56  20.32  4535.4302  0.118221  0.120436 -0.011673
# ...     ...    ...    ...    ...        ...       ...       ...       ...
# 1361  13.82  16.05  17.80  17.24  2055.0100  0.161360  0.109034 -0.031461
# 1362  10.26  11.25  12.47  12.47  2470.3000  0.096491  0.108444  0.000000
# 1363  33.46  28.05  21.60  27.33  2581.0000 -0.161686 -0.229947  0.265278
# 1364  10.97  12.50  13.98  14.05  2297.4200  0.139471  0.118400  0.005007
# 1365  14.08  16.25  18.15  17.22  2087.7900  0.154119  0.116923 -0.051240
#
# [1366 rows x 8 columns]

# %%
#@title
from pycaret.regression import *
s = setup(data = dataset, target = 'SPX', session_id=123)
# Out:
# INFO:logs:PyCaret RegressionExperiment
# INFO:logs:Logging name: reg-default-name
# INFO:logs:ML Usecase: MLUsecase.REGRESSION
# INFO:logs:version 3.0.0
# INFO:logs:Initializing setup()
# INFO:logs:self.USI: 096b
# INFO:logs:self.variable_keys: {'memory', '_gpu_n_jobs_param', 'fold_param', 'exp_name_log', 'fold_shuffle_param', '_all_metrics', 'fold_groups_param_full', '_all_models', 'target_param', 'y', 'imputation_classifier', 'display_container', 'variable_keys', 'data', 'imputation_regressor', 'X_test', 'html_param', 'seed', 'fold_groups_param', 'X_train', 'y_train', 'experiment__', 'logging_param', 'stratify_param', 'exp_id', 'pipeline', 'transform_target_method_param', 'n_jobs_param', 'log_plots_param', 'USI', 'X', '_all_models_internal', 'fold_generator', 'transform_target_param', 'y_test', 'master_model_container', '_ml_usecase', 'iterative_imputation_iters_param', '_available_plots', 'idx', 'gpu_param'}
# INFO:logs:Checking environment
# INFO:logs:python_version: 3.7.15
# INFO:logs:python_build: ('default', 'Oct 12 2022 19:14:55')
# INFO:logs:machine: x86_64
# INFO:logs:platform: Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# INFO:logs:Memory: svmem(total=13616361472, available=11744280576, percent=13.7, used=1765806080, free=8456265728, active=616235008, inactive=4223246336, buffers=117280768, cached=3277008896, shared=1327104, slab=234512384)
# INFO:logs:Physical Core: 1
# INFO:logs:Logical Core: 2
# INFO:logs:Checking libraries
# INFO:logs:pd==1.3.5
# INFO:logs:numpy==1.21.6
# INFO:logs:sklearn==1.0.2
# INFO:logs:lightgbm==3.3.3
# INFO:logs:xgboost==0.90
# WARNING:logs:catboost not found
# WARNING:logs:mlflow not found
# INFO:logs:Set up data.
# INFO:logs:Set up target column.
# INFO:logs:Set up train/test split.
# INFO:logs:Set up folding strategy.
# INFO:logs:Assigning column types.
# INFO:logs:Preparing preprocessing pipeline...
# INFO:logs:Set up simple imputation.
# INFO:logs:Finished creating preprocessing pipeline.
# INFO:logs:Pipeline: Pipeline(memory=Memory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransfomerWrapper(include=['VIX', 'M1', 'M2', 'VIX3M', 'c0', 'c1', 'c2'], transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransfomerWrapper(include=[], transformer=SimpleImputer(fill_value='constant', strategy='constant')))])
# INFO:logs:Creating final display dataframe.
# INFO:logs:Setup display_container:                Description             Value
# 0               Session id               123
# 1                   Target               SPX
# 2              Target type        regression
# 3               Data shape         (1366, 8)
# 4         Train data shape          (956, 8)
# 5          Test data shape          (410, 8)
# 6         Numeric features                 7
# 7               Preprocess              True
# 8          Imputation type            simple
# 9       Numeric imputation              mean
# 10  Categorical imputation          constant
# 11          Fold Generator             KFold
# 12             Fold Number                10
# 13                CPU Jobs                -1
# 14          Log Experiment             False
# 15         Experiment Name  reg-default-name
# 16                     USI              096b
# INFO:logs:Preparing display monitor
#                Description             Value
# 0               Session id               123
# 1                   Target               SPX
# 2              Target type        regression
# 3               Data shape         (1366, 8)
# 4         Train data shape          (956, 8)
# 5          Test data shape          (410, 8)
# 6         Numeric features                 7
# 7               Preprocess              True
# 8          Imputation type            simple
# 9       Numeric imputation              mean
# 10  Categorical imputation          constant
# 11          Fold Generator             KFold
# 12             Fold Number                10
# 13                CPU Jobs                -1
# 14          Log Experiment             False
# 15         Experiment Name  reg-default-name
# 16                     USI              096b
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==0.90
# WARNING:logs:Couldn't import catboost.CatBoostRegressor
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==0.90
# WARNING:logs:Couldn't import catboost.CatBoostRegressor
# INFO:logs:setup() successfully completed in 0.54s...............

# %%
#@title
best = compare_models()
# Out:
#                                     Model       MAE          MSE      RMSE  \
# et                  Extra Trees Regressor  178.9399   71565.1823  265.8409
# rf                Random Forest Regressor  181.3729   77178.2178  276.0202
# knn                 K Neighbors Regressor  204.9690   97499.6645  307.3314
# lightgbm  Light Gradient Boosting Machine  200.3194   96343.4779  306.2968
# gbr           Gradient Boosting Regressor  224.5264   97490.0196  310.8045
# dt                Decision Tree Regressor  200.5504  126079.0877  353.8901
# ada                    AdaBoost Regressor  291.3851  131444.4571  362.0459
# lasso                    Lasso Regression  481.5051  377824.2031  614.1688
# br                         Bayesian Ridge  482.8782  378221.6602  614.4889
# ridge                    Ridge Regression  483.0835  380612.8375  616.4479
# lr                      Linear Regression  484.0686  380880.0625  616.5333
# huber                     Huber Regressor  482.4318  386832.4674  621.4069
# en                            Elastic Net  488.6830  404322.5719  635.5441
# llar         Lasso Least Angle Regression  507.9259  451052.4531  671.0106
# lar                Least Angle Regression  503.4196  448330.1469  660.5109
# omp           Orthogonal Matching Pursuit  530.5887  481038.2402  692.7646
# dummy                     Dummy Regressor  625.0183  579242.3656  760.3139
# par          Passive Aggressive Regressor  588.2653  704134.8567  835.1702
#
#               R2   RMSLE    MAPE  TT (Sec)
# et        0.8724  0.0948  0.0630     0.472
# rf        0.8622  0.0965  0.0631     0.647
# knn       0.8272  0.1079  0.0725     0.070
# lightgbm  0.8267  0.1063  0.0697     0.110
# gbr       0.8257  0.1078  0.0785     0.188
# dt        0.7756  0.1247  0.0701     0.030
# ada       0.7653  0.1271  0.1040     0.136
# lasso     0.3269  0.1930  0.1592     0.030
# br        0.3260  0.1937  0.1595     0.028
# ridge     0.3222  0.1937  0.1599     0.025
# lr        0.3203  0.1956  0.1599     0.066
# huber     0.3138  0.1929  0.1560     0.067
# en        0.2821  0.1989  0.1614     0.026
# llar      0.1997  0.2093  0.1676     0.026
# lar       0.1792  0.2144  0.1671     0.030
# omp       0.1456  0.2135  0.1737     0.029
# dummy    -0.0242  0.2398  0.2070     0.022
# par      -0.2730  0.2416  0.2061     0.027
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 2
# INFO:logs:ExtraTreesRegressor(n_jobs=-1, random_state=123)
# INFO:logs:compare_models() successfully completed......................................

# %%
#@title
et=create_model('et')
# Out:
#            MAE          MSE      RMSE      R2   RMSLE    MAPE
# 0     208.8252  110819.1678  332.8951  0.8066  0.1243  0.0766
# 1     174.0054   67667.5734  260.1299  0.8901  0.0936  0.0610
# 2     175.2045   68682.4267  262.0733  0.8738  0.0896  0.0607
# 3     184.4481   71870.0724  268.0859  0.8794  0.0887  0.0596
# 4     175.5140   74902.8424  273.6838  0.8699  0.0936  0.0585
# 5     182.7041   77175.5111  277.8048  0.8335  0.1032  0.0681
# 6     178.0053   58655.8505  242.1897  0.9024  0.0863  0.0629
# 7     192.7580   83029.8370  288.1490  0.8636  0.1038  0.0677
# 8     162.3086   53990.8770  232.3594  0.8841  0.0841  0.0593
# 9     155.6258   48857.6648  221.0377  0.9211  0.0809  0.0554
# Mean  178.9399   71565.1823  265.8409  0.8724  0.0948  0.0630
# SD     14.1408   16521.6901   29.8967  0.0311  0.0121  0.0059
# INFO:logs:master_model_container: 19
# INFO:logs:display_container: 3
# INFO:logs:ExtraTreesRegressor(n_jobs=-1, random_state=123)
# INFO:logs:create_model() successfully completed......................................

# %%
#@title
f_et=finalize_model(tune_model(et))
# Out:
#            MAE          MSE      RMSE      R2   RMSLE    MAPE
# 0     269.3198  164696.0793  405.8276  0.7126  0.1464  0.0997
# 1     237.8752  103100.6042  321.0928  0.8326  0.1139  0.0836
# 2     241.8557  108611.8131  329.5631  0.8005  0.1157  0.0867
# 3     242.4940  104598.5469  323.4170  0.8245  0.1038  0.0772
# 4     255.7521  114419.6092  338.2597  0.8013  0.1117  0.0837
# 5     246.5995  123737.8772  351.7640  0.7330  0.1245  0.0898
# 6     230.9635   90698.8299  301.1625  0.8491  0.1036  0.0808
# 7     243.9529  111787.8420  334.3469  0.8163  0.1145  0.0831
# 8     210.9939   77840.6280  278.9993  0.8329  0.1002  0.0769
# 9     196.8042   74556.2613  273.0499  0.8796  0.0980  0.0702
# Mean  237.6611  107404.8091  325.7483  0.8082  0.1132  0.0832
# SD     19.7872   24243.5413   35.9565  0.0482  0.0135  0.0076
# INFO:logs:master_model_container: 21
# INFO:logs:display_container: 4
# INFO:logs:ExtraTreesRegressor(n_jobs=-1, random_state=123)
# INFO:logs:tune_model() successfully completed......................................
# INFO:logs:Initializing finalize_model()
# INFO:logs:finalize_model(self=<pycaret.regression.oop.RegressionExperiment object at 0x7f9a06ae8e50>, estimator=ExtraTreesRegressor(n_jobs=-1, random_state=123), fit_kwargs=None, groups=None, model_only=True, experiment_custom_tags=None, display=None)
# INFO:logs:Finalizing ExtraTreesRegressor(n_jobs=-1, random_state=123)
# INFO:logs:Initializing create_model()
# INFO:logs:create_model(self=<pycaret.regression.oop.RegressionExperiment object at 0x7f9a06ae8e50>, estimator=ExtraTreesRegressor(n_jobs=-1, random_state=123), fold=None, round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=True, probability_threshold=None, experiment_custom_tags=None, verbose=False, system=False, add_to_model_list=False, metrics=None, display=None, kwargs={})
# INFO:logs:Checking exceptions
# INFO:logs:Importing libraries
# INFO:logs:Copying training dataset
# INFO:logs:Defining folds
# INFO:logs:Declaring metric variables
# INFO:logs:Importing untrained model
# INFO:logs:Declaring custom model
# INFO:logs:Extra Trees Regressor Imported successfully
# INFO:logs:Starting cross validation
# INFO:logs:Cross validating with KFold(n_splits=10, random_state=None, shuffle=False), n_jobs=-1
# INFO:logs:Calculating mean and std
# INFO:logs:Creating metrics dataframe
# INFO:logs:Finalizing model
# INFO:logs:Uploading results into container
# INFO:logs:master_model_container: 21
# INFO:logs:display_container: 5
# INFO:logs:ExtraTreesRegressor(n_jobs=-1, random_state=123)
# INFO:logs:create_model() successfully completed......................................
# INFO:logs:master_model_container: 21
# INFO:logs:display_container: 4
# INFO:logs:ExtraTreesRegressor(n_jobs=-1, random_state=123)
# INFO:logs:finalize_model() succesfully completed......................................

# %%
#@title
unseen_predictions = predict_model(et, data=data_unseen)
# Out:
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=ExtraTreesRegressor(n_jobs=-1, random_state=123), probability_threshold=None, encoded_labels=False, raw_score=False, drift_report=False, round=4, verbose=True, ml_usecase=None, display=None, replace_labels_in_column=<function _SupervisedExperiment.predict_model.<locals>.replace_labels_in_column at 0x7f9a068c3950>, self=<pycaret.regression.oop.RegressionExperiment object at 0x7f9a06ae8e50>)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor

# %%
#@title
from pycaret.utils import check_metric
check_metric(data_unseen.SPX, unseen_predictions.Label, 'R2')
# Out:
# 0.9105

# %%
#@title
save_model(f_et,'Final ET Model 25Oct2022')
# Out:
# INFO:logs:Initializing save_model()
# INFO:logs:save_model(model=ExtraTreesRegressor(n_jobs=-1, random_state=123), model_name=Final ET Model 25Oct2022, prep_pipe_=Pipeline(memory=Memory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransfomerWrapper(include=['VIX', 'M1', 'M2', 'VIX3M', 'c0', 'c1', 'c2'], transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransfomerWrapper(include=[], transformer=SimpleImputer(fill_value='constant', strategy='constant')))]), verbose=True, use_case=MLUsecase.REGRESSION, kwargs={})
# INFO:logs:Adding model into prep_pipe
# INFO:logs:Final ET Model 25Oct2022.pkl saved in current working directory
# INFO:logs:Pipeline(memory=Memory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransfomerWrapper(include=['VIX', 'M1', 'M2', 'VIX3M', 'c0', 'c1', 'c2'], transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransfomerWrapper(include=[], transformer=SimpleImputer(fill_value='constant', strategy='constant'))),
#                 ['trained_model',
#                  ExtraTreesRegressor(n_jobs=-1, random_state=123)]])
# INFO:logs:save_model() successfully completed......................................
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransfomerWrapper(include=['VIX', 'M1', 'M2', 'VIX3M', 'c0', 'c1', 'c2'], transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransfomerWrapper(include=[], transformer=SimpleImputer(fill_value='constant', strategy='constant'))),
#                  ['trained_model',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=123)]]),
#  'Final ET Model 25Oct2022.pkl')

# %%
x_ax = range(len(data_unseen.SPX))
plt.figure(figsize=(12, 6))
plt.plot(x_ax, data_unseen.SPX, label="original")
plt.plot(x_ax, unseen_predictions.Label, label="predicted")
plt.title("SPX dataset test and predicted data")
plt.xlabel('X')
plt.ylabel('Price')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
plot_model(f_et,plot='feature')
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() successfully completed......................................

# %%
predictions.index=test_data_new_0.index

# %%
#backtesting
vix_df['buy']=np.where(vix_df.signal==1,vix_df['SPX'],np.nan)
vix_df['sell']=np.where(vix_df.signal==-1,vix_df['SPX'],np.nan)
#
predictions['buy']=np.where(predictions.Label==1,vix_df['SPX'],np.nan)
predictions['sell']=np.where(predictions.Label==-1,vix_df['SPX'],np.nan)

# %%
#
plt.figure(figsize =(14,7))
plt.title('price /signals')
plt.plot(vix_df['SPX'],alpha=0.5,label='vix')

plt.scatter(vix_df.index,predictions['buy'],color='green',label='buy signal',marker='^',alpha=1)
plt.scatter(vix_df.index,predictions['sell'],color='red',label='sell signal',marker='^',alpha=1)
plt.xlabel('Date')
plt.ylabel('vix')
plt.legend()
plt.show()

# %%
#
plt.figure(figsize =(14,7))
plt.title('price /signals')
plt.plot(vix_df['SPX'],alpha=0.5,label='SPX')

plt.scatter(vix_df.index,vix_df['buy'],color='green',label='buy signal',marker='^',alpha=1)
plt.scatter(vix_df.index,vix_df['sell'],color='red',label='sell signal',marker='^',alpha=1)
plt.xlabel('Date')
plt.ylabel('vix')
plt.legend()
plt.show()

# %%
predictions['SPX']=vix_df.SPX

# %%
predictions['log_returns']=np.log(predictions['SPX'])-np.log(predictions['SPX']).shift(1)

# %%
# original
#vix_df['strategy_returns']=vix_df.signal.shift(1)*vix_df.log_returns
#vix_df['strategy_returns']
# predictions
predictions['strategy_returns']=predictions.Label.shift(1)*predictions.log_returns
predictions['strategy_returns']
# Out:
# Date
# 2016-03-02         NaN
# 2016-03-03    0.003493
# 2016-03-04    0.000000
# 2016-03-07    0.000000
# 2016-03-08   -0.011304
#                 ...
# 2022-03-04   -0.007966
# 2022-03-07   -0.029963
# 2022-03-08   -0.007260
# 2022-03-09    0.025374
# 2022-03-10   -0.004301
# Name: strategy_returns, Length: 1518, dtype: float64

# %%
plt.figure(figsize =(14,7))
plt.title('$1 investment growth')
plt.plot(np.exp(predictions['log_returns'].dropna()).cumprod(),c='green',label='buy/hold')
plt.plot(np.exp(predictions.strategy_returns.dropna()).cumprod(),c='blue',label='term structure strategy')
plt.legend()
plt.show()
#
print('buy hold',np.exp(predictions['log_returns'].dropna()).cumprod()[-1])
print('strategy',np.exp(predictions['strategy_returns'].dropna()).cumprod()[-1])
# Out:
# buy hold 2.1442875481386405
# strategy 3.038921963205501

# %%
##contangos
contangos_c0= vix_df.loc[vix_df['c0'] >0]
contangos_c1= vix_df.loc[vix_df['c1'] >0]
contangos_c2= vix_df.loc[vix_df['c2'] >0]
#backwardation
back_c0= vix_df.loc[vix_df['c0'] <=0]
back_c1= vix_df.loc[vix_df['c1'] <=0]
back_c2= vix_df.loc[vix_df['c2'] <=0]

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score

# %%
b=back_c0.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1).iloc[:,0:8]
c=contangos_c0.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1).iloc[:,0:8]
b1=back_c1.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1).iloc[:,0:8]
c1=contangos_c1.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1).iloc[:,0:8]
b2=back_c2.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1).iloc[:,0:8]
c2=contangos_c2.drop(['rolling 1m return','after_1m','rolling 1w return','after_1w','signal_weekly','SP500 return','SPX'],axis=1).iloc[:,0:8]

# %%
c.shape,c1.shape,c2.shape,b.shape,b1.shape,b2.shape
# Out:
# ((1209, 8), (1284, 8), (926, 8), (309, 8), (234, 8), (592, 8))

# %%
#accuracy of backwardation 0
X = b.drop('signal', axis = 1)
y = b['signal']
y_pred_cv = cross_val_predict(lightgbm_model, X, y, cv=10)
accuracy_score(y, y_pred_cv)
# Out:
# 0.517799352750809

# %%
#accuracy of backwardation 1
X = b1.drop('signal', axis = 1)
y = b1['signal']
y_pred_cv = cross_val_predict(lightgbm_model, X, y, cv=10)
accuracy_score(y, y_pred_cv)
# Out:
# 0.5683760683760684

# %%
#accuracy of backwardation 2
X = b2.drop('signal', axis = 1)
y = b2['signal']
y_pred_cv = cross_val_predict(lightgbm_model, X, y, cv=10)
accuracy_score(y, y_pred_cv)
# Out:
# 0.5405405405405406

# %%
#accuracy of contango 0
X = c.drop('signal', axis = 1)
y = c['signal']
y_pred_cv = cross_val_predict(lightgbm_model, X, y, cv=10)
accuracy_score(y, y_pred_cv)
# Out:
# 0.5409429280397022

# %%
#accuracy of contango 1
X = c1.drop('signal', axis = 1)
y = c1['signal']
y_pred_cv = cross_val_predict(lightgbm_model, X, y, cv=10)
accuracy_score(y, y_pred_cv)
# Out:
# 0.5046728971962616

# %%
#accuracy of contango 1
X = c2.drop('signal', axis = 1)
y = c2['signal']
y_pred_cv = cross_val_predict(lightgbm_model, X, y, cv=10)
accuracy_score(y, y_pred_cv)
# Out:
# 0.5032397408207343

# %% [markdown]
# # **SMA VIX Trading Strategy 1**
# Sell VIX 1M future when moving avarage 15th percentil and buy VIX 1M future  when value is arrount 85th percentil

# %%
df_new= vix_df

# %%
# gettting SMA for SPX, Estimation the daily change and log return adn ratio
df_new['SMA']=SMA(df_new,21,'VIX')
df_new['Simple_Returns']=df_new.pct_change(1)['SPX']
df_new['log_returns']=np.log(1+df_new['Simple_Returns'])
df_new['Ratios']=df_new['VIX']/df_new['SMA']

# %%
plt.figure(figsize =(14,7))
plt.title('Simple Moving Average of VIX')
plt.plot(df_new['SMA'])

# %%
percentiles = [15,20,50,80,85]

# %%
ratios =df_new['Ratios'].dropna()
percentile_values =np.percentile(ratios,percentiles)
percentile_values
# Out:
# array([0.87177248, 0.88753983, 0.96955485, 1.09989165, 1.13839692])

# %%
plt.figure(figsize =(14,7))
plt.title('Ratios [VIX/SMA]')
df_new['Ratios'].dropna().plot(legend= True)
plt.axhline(percentile_values[0],c='green',label='15th')
plt.axhline(percentile_values[2],c='red',label='50th')
plt.axhline(percentile_values[-1],c='yellow',label='85th')
plt.legend()
plt.show()

# %%
sell = percentile_values[-1]
buy = percentile_values[0]
df_new['positions'] = np.where(df_new.Ratios> sell,-1,np.nan)
df_new['positions'] = np.where(df_new.Ratios< buy,1,df_new['positions'])
df_new['positions']=df_new['positions'].ffill()
df_new['buy']=np.where(df_new.positions==1,df_new['VIX'],np.nan)
df_new['sell']=np.where(df_new.positions==-1,df_new['VIX'],np.nan)

# %%
plt.figure(figsize =(14,7))

plt.title('VIX1M price /signals')
plt.plot(df_new['VIX'],alpha=0.5,label='SP500')
plt.plot(df_new['SMA'],alpha=0.5,label='SMA')
plt.scatter(df_new.index,df_new['buy'],color='green',label='buy signal',marker='^',alpha=1)
plt.scatter(df_new.index,df_new['sell'],color='red',label='sell signal',marker='^',alpha=1)
plt.xlabel('Date')
plt.ylabel('vix')
plt.legend()
plt.show()

# %%
plt.figure(figsize =(20,14))
fig,ax = plt.subplots(figsize =(20,14))
ax.plot(df_new['SPX'],alpha=0.5,label='SP500')
plt.scatter(df_new.index,df_new['buy'],color='green',label='buy signal',marker='^',alpha=1)
plt.scatter(df_new.index,df_new['sell'],color='red',label='sell signal',marker='^',alpha=1)
plt.xlabel('Date')
plt.ylabel('vix')
plt.legend()
# set x-axis label

# set y-axis label
ax.set_ylabel("SP500",
              color="red",
              fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object

ax2.plot(df_new['VIX'],alpha=0.5,label='vix',color='blue')
ax2.set_ylabel("VIX",color="blue",fontsize=14)
plt.show()

# %%
df_new['VIX1M_returns']=np.log(df_new['M1'])-np.log(df_new['M1']).shift(1)

# %%
df_new['strategy_returns']=df_new.positions.shift(1)*df_new.VIX1M_returns
df_new['strategy_returns']
# Out:
# Date
# 2016-03-02         NaN
# 2016-03-03         NaN
# 2016-03-04         NaN
# 2016-03-07         NaN
# 2016-03-08         NaN
#                 ...
# 2022-03-04   -0.073006
# 2022-03-07   -0.073552
# 2022-03-08    0.011938
# 2022-03-09    0.064734
# 2022-03-10    0.054588
# Name: strategy_returns, Length: 1518, dtype: float64

# %%
#plot cumalative returns
plt.figure(figsize =(14,7))
plt.title('1 dollar investment growth')
plt.plot(np.exp(df_new['VIX1M_returns'].dropna()).cumprod(),c='green',label='buy/hold')
plt.plot(np.exp(df_new.strategy_returns.dropna()).cumprod(),c='blue',label='mean reverting strategy')
plt.legend()
plt.show()

# %%
print('buy hold',np.exp(df_new['VIX1M_returns'].dropna()).cumprod()[-1]-1)
print('strategy',np.exp(df_new['strategy_returns'].dropna()).cumprod()[-1]-1)
# Out:
# buy hold 0.5699481865284961
# strategy 61.340036906057485
